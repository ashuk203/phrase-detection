# %%
import pickle
import wikipedia 
import spacy
import urllib

# %%
nlp = spacy.load("en_core_web_md")

# %%
with open("./reprod/run_v9_fscore/cm_precision.pickle", "rb") as f:
    prec_map = pickle.load(f)

# %%
with open("./reprod/run_v9_fscore/cm_recall.pickle", "rb") as f:
    rec_map = pickle.load(f)

# %%
v6_words = [('natural language processing', 100), ('artificial intelligence', 100), ('databases', 100), ('constraint programming', 100), ('machine learning', 100), ('neural networks', 1.0431075423678948), ('deep reinforcement learning', 1.0018178050972293), ('neural machine translation', 1.0009245362518895), ('visual question answering', 1.000467765222335), ('object recognition', 1.000342645941052), ('representation learning', 1.0002022738467469), ('benchmark datasets', 1.000111073695409), ('word embedding', 1.0001060587976176), ('high level', 1.0000827855302032), ('statistical machine translation', 1.0000757570122674), ('data', 1.0000747368731664), ('activation functions', 1.0000734312652135), ('data set', 1.0000709105286245), ('image segmentation', 1.0000696285811368), ('question answering', 1.000065580820084), ('neural machine', 1.0000594000219643), ('loss function', 1.0000589000285047), ('language understanding', 1.0000534113713113), ('language processing', 1.000048161735354), ('lstm rnn', 1.0000432875569498), ('sequence labeling', 1.0000429833960542), ('multi layer', 1.0000357514997482), ('natural language understanding', 1.000032231407001), ('evolutionary algorithms', 1.0000321813182556), ('latent variables', 1.0000321433637458), ('tasks', 1.0000300771067328), ('spectral clustering', 1.0000285718874726), ('images', 1.0000283709375202), ('backpropagation', 1.0000262885703148), ('deep learning algorithms', 1.000025556493101), ('networks', 1.000024784484955), ('neural language modeling', 1.0000242471667546), ('multi view', 1.0000241685387108), ('adversarial perturbations', 1.000022862574725), ('natural language text', 1.000022385905325), ('adversarial examples', 1.000022308872928), ('context', 1.0000213388254044), ('word error', 1.000019863486129), ('higher level inference', 1.0000195363332531), ('textual entailment', 1.0000194429640614), ('domain knowledge', 1.0000193434657125), ('neural sequence', 1.0000193305328404), ('conditional language models', 1.000019258746048), ('structured prediction problems', 1.0000185418981553), ('multi label data', 1.0000183975541448), ('classification', 1.00001829684118), ('prior knowledge', 1.0000182280510201), ('classification tasks', 1.0000180320799945), ('linear support vector', 1.0000178909038875), ('unsupervised domain', 1.0000174677447584), ('information extraction', 1.0000161598400883), ('visual object recognition', 1.000015917474317), ('gradient based', 1.0000146167278658), ('dnn', 1.0000145170387673), ('neural network decisions', 1.000013828903243), ('interior point methods', 1.000013457714925), ('dynamic programming languages', 1.000013457714925), ('traditional computer vision', 1.0000132929039136), ('supervised image recognition', 1.000013251343356), ('computer', 1.0000130258993725), ('neural networks gaussian', 1.0000128832481139), ('concept drift', 1.0000127106942474), ('better performance', 1.0000125278826584), ('adversarial samples inputs', 1.0000125109634979), ('multi language image', 1.0000125109634979), ('many classification problems', 1.0000121339409616), ('better speech recognition', 1.0000121199935195), ('application domains', 1.0000118355350358), ('artificial intelligence psychology', 1.0000117789632006), ('sequence tasks', 1.0000117195869374), ('hierarchical reinforcement', 1.000011684354754), ('acoustic models', 1.0000115097519047), ('neural sequence labeling', 1.0000114108685005), ('neural encoder decoder', 1.0000114088313705), ('neural networks requires', 1.000011339534224), ('training algorithms', 1.000011233912975), ('graphical processing units', 1.0000110631072954), ('many tasks', 1.0000110486013967), ('different architectures', 1.0000108100030456), ('svms parameters', 1.0000107325458263), ('simple preprocessing steps', 1.00001071738334), ('statistical language models', 1.0000105561151338), ('universal perturbations', 1.0000104928520785), ('layer', 1.0000104887303078), ('deep q networks', 1.000010336607698), ('many cheminformatics software', 1.000010306585213), ('extensible self service', 1.0000102703450224), ('error detection', 1.0000101853475245), ('deep auto encoders', 1.0000100259357871), ('input data', 1.00000992405852), ('encode data points', 1.0000097741768579), ('human robot teams', 1.0000097741768579), ('output', 1.0000097327717479), ('feature representations', 1.0000097180985332), ('word models', 1.000009690884989), ('multilingual recognition systems', 1.0000096802121903), ('various bigram types', 1.0000096802121903), ('output layer', 1.0000096493375603), ('neural networks involves', 1.000009594982128), ('deep learning run', 1.000009594982128), ('recurrent networks based', 1.000009594982128), ('web document', 1.0000095820757262), ('code generation', 1.0000095820757262), ('optical character recognition', 1.0000095767214372), ('real world robotics', 1.0000095703970322), ('neural image captioning', 1.0000095703970322), ('open information extraction', 1.0000095703970322), ('different kernel functions', 1.0000095620419793), ('joint optimization framework', 1.0000095297956437), ('subsequent network layers', 1.0000093832079493), ('probabilistic models', 1.0000093163530517), ('visual recognition', 1.0000092719136804), ('unsupervised evaluation metrics', 1.0000089887653547), ('new regularization methods', 1.0000089887653547), ('stochastic control', 1.0000089770335836), ('large datasets', 1.0000089496386289), ('classifier trained', 1.0000089161269177), ('discrete memory representation', 1.000008853739438), ('stochastic optimization processes', 1.0000087227072212), ('distributional semantics composing', 1.0000086430421162), ('big data', 1.0000086095053131), ('backpropagation algorithm', 1.000008448874956), ('unsupervised learning leveraging', 1.0000084319490878), ('language generation', 1.0000083665809865), ('software', 1.0000083300925848), ('traditional auto encoder', 1.0000082973189974), ('different application', 1.0000082275027267), ('sequential data', 1.0000082228471174), ('other network structures', 1.0000082103021408), ('text modeling', 1.0000080980501809), ('natural language dialog', 1.0000080980222963), ('stochastic loss selection', 1.0000079414900631), ('search', 1.0000078890779156), ('lower error solutions', 1.0000078193338435), ('error rates', 1.0000077899292834), ('prior class probabilities', 1.0000077835392926), ('real world data', 1.0000077299289512), ('content information', 1.0000076972098775), ('image description', 1.0000076442870882), ('source language', 1.0000075196158502), ('low resource language', 1.0000074371358603), ('mathematical language processing', 1.0000074371358603), ('art rnn', 1.000007430100244), ('less computation', 1.0000072848169617), ('traditional data structures', 1.0000072601503578), ('computing', 1.0000072365305301), ('mapping codes', 1.0000071519223939), ('novel quantization scheme', 1.0000071473382186), ('variable length sequences', 1.0000070829852794), ('current scheduling techniques', 1.000007037397708), ('structural support vector', 1.0000069937426672), ('big data analysis', 1.0000069937426672), ('convolutional', 1.0000068907544581), ('new tasks', 1.0000068788643153), ('sequential control learning', 1.000006687402064), ('structured output', 1.0000066281036908), ('building blocks', 1.000006627663279), ('real world images', 1.0000065687051956), ('programming language', 1.0000063867537916), ('end user', 1.0000063366495249), ('directional wavelet domain', 1.000006257556925), ('deep learning methodology', 1.000006257556925), ('supervised separation learning', 1.0000062229827937), ('neural dependency', 1.0000062042845381), ('temporal variables describing', 1.0000061058870657), ('incremental learning using', 1.0000061058870657), ('stream data', 1.0000060490143818), ('real time classification', 1.0000059322183414), ('sentence embeddings', 1.0000059113946287), ('different application areas', 1.0000058772605114), ('different learning problems', 1.0000058772605114), ('recognition', 1.0000058650152603), ('multi class tasks', 1.0000058644946508), ('generalization', 1.000005814905356), ('backpropagation training', 1.0000058097459004), ('medical imaging', 1.0000057512258154), ('sentiment classification', 1.0000056878661643), ('dynamical systems', 1.0000056863539806), ('real world pattern', 1.00000566638421), ('robot', 1.0000055665025998), ('performance', 1.0000055378427977), ('conversational telephone speech', 1.0000055315383487), ('multi label image', 1.0000055213717252), ('timit', 1.000005519502847), ('particular source side', 1.0000054735272708), ('word lstm', 1.0000054690072215), ('algorithm known', 1.0000054316762206), ('amazon alexa', 1.0000054188317564), ('high quality', 1.000005349396858), ('fewer parameters', 1.000005279566037), ('computer graphics', 1.0000052108018158), ('full batch normalization', 1.0000051858163055), ('time series', 1.000005168935902), ('small scale tasks', 1.0000051532793284), ('relation classification', 1.000005120618011), ('successful policy optimisation', 1.0000050825600435), ('remote sensing', 1.0000050162314273), ('visual object', 1.0000049757708906), ('short text classification', 1.000004958084428), ('multimodal image alignment', 1.000004958084428), ('most feature engineering', 1.000004958084428), ('higher level representation', 1.000004958084428), ('kernel based', 1.000004953679697), ('dual sequence modeling', 1.0000049531543584), ('hand crafted', 1.000004924786869), ('lstm language', 1.0000049181038382), ('complex data', 1.0000048946657571), ('high quality data', 1.0000048400943817), ('multi sensor accelerometer', 1.0000047991260008), ('using', 1.0000047900095688), ('real world deployment', 1.000004785187067), ('optimization models', 1.000004743903643), ('network parameters', 1.0000046843709305), ('user specified', 1.0000046667705973), ('edge device', 1.000004645843431), ('art methods', 1.0000046263491207), ('decision making', 1.0000045960802606), ('problem instances', 1.0000045926141583), ('execution efficiency', 1.0000045926141583), ('inference steps', 1.0000045908314994), ('user inputs', 1.0000045821391537), ('such tasks', 1.0000045509096707), ('original data', 1.0000045445272654), ('variational auto', 1.0000045039607157), ('cross modality feature', 1.0000044943725777), ('different network', 1.0000044925455236), ('discrete memory', 1.0000044565662725), ('sequence framework', 1.0000044324525457), ('real world scenarios', 1.0000044286720866), ('hidden state representations', 1.0000044170949414), ('novel communication strategy', 1.00000436781173), ('error corrections', 1.0000043382078925), ('english translation task', 1.0000043006260477), ('structured learning', 1.0000042682830768), ('spoken language understanding', 1.0000042455593767), ('neuron bias', 1.0000042343115902), ('optimality guarantees', 1.0000041832715723), ('feature representation', 1.000004168883821), ('3d shapes', 1.000004162055685), ('content', 1.000004160868717), ('large dnn models', 1.000004148650893), ('output weights', 1.0000041371652113), ('efficient learning', 1.0000041249857379), ('artificial networks', 1.0000040875978748), ('unstructured environments', 1.0000040856866521), ('arbitrary orientations', 1.0000040856866521), ('resource constrained', 1.0000040834230814), ('imagenet', 1.000004076360877), ('such models using', 1.0000040705872348), ('mnist data', 1.000004068927953), ('complex behaviors including', 1.0000040654971203), ('remote sensing imagery', 1.0000040607974248), ('iterative algorithms', 1.0000040571085698), ('github', 1.0000040556360934), ('latent embedding', 1.0000040424917502), ('image signals', 1.000004018536235), ('problem domains', 1.000004018536235), ('input pixels', 1.0000040139496498), ('binary encodings', 1.0000039970479255), ('hyperparameter', 1.0000039192622276), ('decode brain states', 1.000003909659279), ('perceptron method', 1.0000039095228281), ('rnns integrating', 1.0000039028971046), ('multiply adds', 1.0000039028971046), ('computational time', 1.0000038931313682), ('handwritten digits', 1.000003885538929), ('convolutional networks', 1.0000038780850296), ('program models', 1.0000038750168057), ('large domains', 1.0000038715613695), ('generating images', 1.0000038708787555), ('high confidence', 1.0000038509630222), ('such data', 1.0000038507520703), ('latent task', 1.0000038430830314), ('image tagging', 1.0000038430830314), ('photo editing', 1.0000038390715231), ('convolutional nets', 1.0000038287776052), ('morphological segmentation', 1.000003826218756), ('multiple layers', 1.0000037605819578), ('vector semantics', 1.000003746779376), ('physics simulation', 1.0000037466054714), ('optimisation problems', 1.000003731497397), ('factorization machine', 1.00000372583402), ('multiple solution mechanisms', 1.000003691633341), ('human language understanding', 1.0000036809110961), ('online learning', 1.0000036779680432), ('neural data', 1.0000036160673538), ('information represented', 1.0000036026737098), ('bayesian optimization', 1.000003587978009), ('patterns', 1.00000357877712), ('machines', 1.0000035674610375), ('time convolution', 1.0000035635265314), ('non lstm', 1.0000035549107027), ('sample', 1.0000035493835802), ('character', 1.0000035466006423), ('various relation learning', 1.0000035414863686), ('few shot learning', 1.0000035414863686), ('stochastic search', 1.0000035378896532), ('video prediction', 1.0000034896311871), ('multiple choice based', 1.0000034890737581), ('human motion', 1.0000034756221623), ('input vector', 1.0000034692396815), ('input module', 1.0000034678931586), ('different discourse corpora', 1.0000034572078822), ('abstractions learning', 1.000003452562046), ('firefly algorithm', 1.0000034444586414), ('conventional rnns', 1.0000034298358624), ('art parsing', 1.0000034192894258), ('deep bayesian', 1.0000034033571474), ('linear regions', 1.0000033965426611), ('domain experts', 1.0000033405997686), ('text samples', 1.0000033146255594), ('unaligned text style', 1.0000033128193768), ('data utilized', 1.000003302450405), ('filter maps', 1.0000033009392943), ('language expressions', 1.0000033009392943), ('latent vectors', 1.0000033009392943), ('architecture search', 1.0000033009392943), ('large applications', 1.0000032895462265), ('computational tractability', 1.0000032895462265), ('large graphs', 1.0000032895462265), ('various forms viewed', 1.0000032714472467), ('system supported', 1.000003270624425), ('environment', 1.0000032690498495), ('computational efficiency', 1.0000032270495653), ('authorship attribution', 1.0000032222391992), ('unbounded memory', 1.0000032162628039), ('document understanding', 1.0000031953560682), ('many content words', 1.0000031873371673), ('reservoir computing', 1.0000031574199681), ('datasets including', 1.0000031523387862), ('variational autoencoders', 1.000003128188576), ('large scale service', 1.0000031277262005), ('abstract data', 1.0000031240117626), ('task performance', 1.0000031166456957), ('high quality features', 1.0000031114865562), ('reasonable dimension d', 1.0000031114865562), ('different image', 1.0000030842919228), ('extensible self', 1.0000030702428082), ('arbitrary inputs', 1.0000030702428082), ('3d reconstruction', 1.0000030702428082), ('black boxes', 1.0000030609885504), ('sequential control', 1.000003022084529), ('faster convergence', 1.0000030162870566), ('pixels', 1.0000030158288375), ('approximation errors', 1.0000030139006624), ('subspaces layers', 1.0000030139006624), ('neural network based', 1.0000030101307589), ('control problem', 1.0000029958765468), ('context information', 1.0000029806661053), ('multiple atari', 1.0000029788767595), ('system need', 1.00000297329449), ('solutions', 1.0000029641107198), ('easier images', 1.000002960591117), ('multilinear filters', 1.0000029437818747), ('classification error', 1.0000029437818747), ('similar architectures', 1.0000029198471052), ('loss', 1.000002911439096), ('cognitive databases using', 1.0000029075606198), ('local optima', 1.0000029043441403), ('genomics', 1.0000028961605998), ('gaussian input', 1.000002894636058), ('task completion', 1.0000028887434425), ('simulated robotics', 1.0000028761567235), ('hierarchical memory', 1.0000028715818297), ('heuristic methods', 1.0000028715818297), ('speech frames', 1.0000028703813773), ('performance robustness', 1.0000028703813773), ('words representation', 1.0000028692672174), ('dialog state', 1.0000028692672174), ('generation', 1.0000028628028563), ('self driving', 1.000002860914032), ('methods using', 1.0000028521156166), ('intelligent text', 1.0000028509394379), ('2d', 1.000002847703551), ('intrusion detection', 1.0000028447845468), ('second order representations', 1.000002836275951), ('different target words', 1.0000028331880915), ('linear system dynamics', 1.0000028331880915), ('image infer', 1.0000028287176166), ('simple transformations', 1.00000279777011), ('weight normalization', 1.0000027888457705), ('frameworks', 1.0000027698240823), ('actual fitness evaluations', 1.0000027657653496), ('complex learning tasks', 1.0000027657653496), ('evolutionary product unit', 1.0000027657653496), ('parser states', 1.0000027652268), ('unsupervised', 1.0000027639151938), ('complex behaviors', 1.0000027633787443), ('data processing', 1.000002761891825), ('sentence simplification', 1.000002759625094), ('e commerce', 1.000002748393438), ('lstm cell', 1.000002747230661), ('unseen scenarios e', 1.0000027367598905), ('words model', 1.0000027268621128), ('machine understanding', 1.0000027268621128), ('particle swarms', 1.0000027268621128), ('parameters shared', 1.0000026949926843), ('dynamic data', 1.0000026931130082), ('human intelligence', 1.00000268666956), ('sparse prediction', 1.0000026802182849), ('orthogonal regularization', 1.0000026802182849), ('prediction performance', 1.0000026798375425), ('web corpora', 1.0000026798375425), ('clustering algorithm', 1.0000026797345667), ('disentangle input', 1.0000026605943717), ('standard architectures', 1.0000026588717816), ('deep inference', 1.0000026588717816), ('unlabeled target', 1.0000026405912885), ('practical hardware', 1.0000026316361155), ('offline storage', 1.0000026316361155), ('network given', 1.0000026180555905), ('machine question', 1.0000026143814782), ('concept', 1.0000026043039985), ('test error', 1.0000025915989295), ('continual learning', 1.0000025903576086), ('different layers', 1.000002585648997), ('external simulation', 1.0000025853883485), ('decision', 1.0000025810047724), ('many tasks thanks', 1.0000025766363447), ('configurable network', 1.0000025730094155), ('translation using', 1.000002551892537), ('basic structures', 1.0000025508108774), ('state action', 1.0000025395670296), ('graphs', 1.0000025380907418), ('unlabeled observations', 1.000002537630279), ('text sources', 1.0000024789736341), ('many computer', 1.0000024776637007), ('local learning', 1.000002446161779), ('k digit', 1.0000024398236453), ('dynamic memory', 1.0000024218225583), ('future feature frames', 1.0000024200442625), ('unstructured tasks', 1.0000024123328415), ('problems involves', 1.000002401781031), ('practical applications', 1.0000023881475637), ('attributes', 1.000002386335278), ('model predictions', 1.000002382077461), ('alexnet', 1.0000023786553813), ('network are', 1.0000023786348846), ('multiple patterns', 1.000002376399069), ('linear time', 1.0000023665019964), ('several data', 1.0000023625567018), ('deep components', 1.000002354631489), ('artificial classes', 1.0000023398067945), ('building block', 1.0000023359400945), ('synaptic cluster driven', 1.0000023260478195), ('stack contents', 1.0000023245792988), ('consistency performance', 1.0000023238943099), ('source learning', 1.0000023100486948), ('domain generalization', 1.0000023091689096), ('move prediction', 1.0000023091689096), ('news articles', 1.0000023091689096), ('specific applications', 1.0000023026812224), ('logarithmic time', 1.0000023026812224), ('semantic classification', 1.0000023026812224), ('complicated queries', 1.0000023026812224), ('segmentation techniques', 1.0000022963044426), ('gan models', 1.0000022963044426), ('vqa', 1.000002293521273), ('gradient estimators', 1.000002259836729), ('segmentations produced', 1.0000022516695475), ('multimodal learning', 1.0000022516695475), ('problems demonstrate', 1.0000022516695475), ('complex dependencies', 1.0000022513828766), ('cheap hardware', 1.0000022513828766), ('bayesian model', 1.0000022354987461), ('segmentation quality', 1.0000022331974534), ('model used', 1.0000022299700386), ('iterative inference', 1.0000022103869768), ('neural nlu systems', 1.0000022085450317), ('learning method', 1.0000022068397094), ('concave optimization', 1.0000021930296155), ('analogy detection', 1.0000021786507571), ('group sparsity', 1.0000021691015937), ('parameter convergence', 1.0000021691015937), ('vision sensors', 1.0000021691015937), ('other data', 1.000002157116767), ('different atari', 1.000002157116767), ('output scalars', 1.0000021563170478), ('gp trees', 1.0000021527852605), ('projection views', 1.0000021527852605), ('network pruning', 1.0000021527852605), ('many classification', 1.0000021517628639), ('general applications', 1.0000021513652197), ('recent image', 1.0000021513652197), ('new vertices', 1.0000021270968598), ('discrete latent', 1.0000021270968598), ('online viewer', 1.0000021270968598), ('arbitrary size', 1.0000021270968598), ('random indexing', 1.0000021270968598), ('invariant classifiers', 1.0000021256752794), ('hebbian plasticity', 1.0000021256752794), ('closed loop control', 1.0000021248903161), ('medical event detection', 1.0000021248903161), ('parameters ii', 1.0000021015580867), ('information delivered', 1.0000021015580867), ('layers required', 1.0000021015580867), ('features derived', 1.000002094014856), ('covariance', 1.0000020758452626), ('structured exploration strategies', 1.0000020743232951), ('acoustic source separation', 1.0000020743232951), ('entire source sentence', 1.0000020743232951), ('plausible answer space', 1.0000020743232951), ('low level sensor', 1.0000020743232951), ('noise ratio', 1.0000020693505662), ('generator networks', 1.0000020693505662), ('interpretable cad', 1.0000020659146742), ('image representation', 1.0000020644234597), ('possible classes', 1.0000020627665005), ('sequences', 1.0000020421412832), ('nonlinear discriminators', 1.0000020369652414), ('learnable parameters', 1.0000020369652414), ('residual networks showing', 1.0000020352915462), ('tanh activation', 1.0000020334072257), ('stochastic optimization', 1.0000020235828877), ('latent representation', 1.0000020217398793), ('neural move', 1.0000020207419094), ('efficient structures', 1.0000020207419094), ('video sharing', 1.000002009266099), ('speech engineering', 1.000002009266099), ('content selection', 1.000002009266099), ('gaussian mixtures', 1.0000019998737208), ('feature extractors', 1.000001986160377), ('hidden objects', 1.0000019776274915), ('fast inference', 1.0000019737264374), ('generalized constraint', 1.0000019737264374), ('linear classification', 1.0000019516768746), ('decision based', 1.0000019514466483), ('principle provides', 1.0000019514466483), ('log transformed', 1.0000019506223157), ('unlabeled set', 1.0000019468605517), ('scheme', 1.0000019447820323), ('suboptimal solutions', 1.0000019390406347), ('adversarial sample', 1.0000019362284895), ('3d rotations', 1.0000019215396696), ('parameter sharing', 1.0000019215396696), ('weak labels', 1.0000019152954072), ('functional layers', 1.0000019143869703), ('individual apis', 1.0000019143869703), ('semantic structures', 1.0000019143869703), ('arbitrary length', 1.0000019143869703), ('algorithms combine', 1.0000018952757352), ('kernels', 1.000001874038332), ('gradient vectors', 1.0000018703436926), ('sentence pairs', 1.000001865746958), ('interest roi', 1.000001865746958), ('complex problems', 1.0000018640748665), ('accelerated performance', 1.0000018640748665), ('web search', 1.0000018547136706), ('real world settings', 1.0000018404538544), ('clinical data sets', 1.0000018404538544), ('remote sensing technologies', 1.0000018404538544), ('speedup', 1.0000018392810532), ('multiple data', 1.0000018363078758), ('redundant robots', 1.0000018286601418), ('standard computer', 1.0000018286601418), ('high dimension', 1.0000018286601418), ('neural dialogue', 1.0000018286601418), ('human qualia', 1.0000018225476521), ('individual data', 1.0000018080320423), ('generative modules', 1.0000018080320423), ('various network', 1.0000018080320423), ('random weights', 1.0000018080320423), ('spikes implement', 1.0000018013352325), ('speed', 1.000001796741188), ('target distribution', 1.0000017962653474), ('translation pair', 1.0000017962653474), ('encoder output', 1.0000017962653474), ('art bits', 1.0000017962653474), ('model simulations', 1.0000017951298046), ('nlu models', 1.0000017865575637), ('full batch training', 1.0000017726715267), ('low dose ct', 1.0000017707416164), ('medical text domain', 1.0000017707416164), ('general nonconvex', 1.0000017544233075), ('dialogue applications', 1.0000017429202261), ('sequence transformation', 1.0000017429202261), ('generator network', 1.0000017429202261), ('simple word hypotheses', 1.0000017286024472), ('spectral variations', 1.000001722338805), ('ensemble formulations', 1.0000017210918055), ('stochastic estimates', 1.0000017210918055), ('stochastic textures', 1.0000017154570395), ('recurrent batch', 1.0000017153388747), ('traditional data', 1.0000017016771259), ('3d recovery', 1.0000016906025906), ('word2vec skip', 1.0000016905391205), ('large amounts', 1.00000168690246), ('response', 1.0000016616648826), ('time enabled', 1.000001659675715), ('visitors identify', 1.0000016512238392), ('tasks having', 1.0000016512238392), ('nonlinear latent', 1.0000016480226381), ('cognitive science suggesting', 1.0000016357222856), ('amazon', 1.0000016327152161), ('many output', 1.0000016158669345), ('low precision', 1.0000016081301089), ('only simulation', 1.0000016081301089), ('joint distribution', 1.0000015987940432), ('transparency', 1.0000015954640573), ('isotropic variance', 1.0000015953222205), ('available corpora', 1.0000015953222205), ('primitive actions', 1.0000015953222205), ('possible imaging', 1.0000015953222205), ('item content', 1.0000015812987137), ('input dropout', 1.000001578708738), ('feature construction', 1.000001578708738), ('different time scales', 1.0000015638618773), ('src applied', 1.0000015604975483), ('similarities', 1.0000015245697211), ('artificial system', 1.0000015123729422), ('internal representation', 1.0000015123729422), ('space', 1.0000015103233482), ('unseen data', 1.000001508142391), ('human similarity', 1.0000015026233076), ('transparency makes', 1.0000015011124683), ('cnn based', 1.000001498576717), ('anns', 1.0000014938074175), ('succinctness robustness', 1.000001490331942), ('deep methods', 1.0000014889673268), ('semantic roles', 1.0000014889673268), ('continuous online', 1.0000014889673268), ('interesting applications', 1.0000014889673268), ('acoustic tokens', 1.0000014879722212), ('feature distributions', 1.0000014863844615), ('variational bayesian', 1.000001483220252), ('max norm', 1.0000014781071103), ('medical paper abstracts', 1.0000014723628126), ('many cases representation', 1.0000014723628126), ('human language communication', 1.0000014723628126), ('universal perturbations reveals', 1.0000014537792532), ('such generators captures', 1.0000014537792532), ('sentiment compression', 1.0000014524333107), ('engineering applications', 1.0000014524333107), ('whole network', 1.0000014403551312), ('background knowledge', 1.0000014402382007), ('target answers', 1.000001437544182), ('pairwise sequence', 1.0000014351896587), ('prediction adaptation', 1.0000014351896587), ('inverse models', 1.0000014346325796), ('accuracy loss', 1.00000142660676), ('current learning', 1.0000014254687029), ('probabilistic selection', 1.0000014135201054), ('multiple feature', 1.0000014127291128), ('many examples', 1.0000014058512456), ('need', 1.0000014051319226), ('other hmm', 1.000001400417859), ('local normalization', 1.000001400417859), ('decode brain', 1.000001400417859), ('noisy acquisition', 1.000001400417859), ('large storage', 1.0000013983868663), ('sophisticated regularization', 1.0000013937126115), ('table', 1.0000013917197306), ('difference', 1.000001390251236), ('paths', 1.000001383342935), ('vocabulary oov word', 1.0000013828817187), ('novel chemical properties', 1.0000013828817187), ('flexible krylov subspace', 1.0000013828817187), ('inter beat intervals', 1.0000013828817187), ('semantic boundaries', 1.000001382612444), ('finite samples', 1.000001382612444), ('input signal', 1.0000013736143871), ('learning process', 1.0000013736143871), ('ancestor', 1.000001370709696), ('visual attributes', 1.0000013683373254), ('abstraction', 1.0000013675404649), ('vae', 1.000001353035871), ('network making', 1.0000013474954343), ('model construction', 1.0000013399178735), ('input compensating', 1.0000013379814263), ('standard domain', 1.00000133535745), ('holistic information', 1.00000133535745), ('end system', 1.0000013302963011), ('subgraphs', 1.0000013277480317), ('transformations', 1.0000013233627414), ('experimental analysis', 1.000001318417893), ('exploratory data', 1.000001315817192), ('early recognition', 1.000001315817192), ('argmax', 1.0000013147515745), ('discourse relation', 1.0000013071898848), ('rnn receives', 1.00000129961726), ('different languages', 1.0000012982548974), ('mtl model', 1.0000012963195248), ('spectrograms state', 1.0000012937896707), ('other machine', 1.0000012926933388), ('different environments', 1.0000012926933388), ('interaction time', 1.0000012916706003), ('weight pruning', 1.0000012916706003), ('different contexts', 1.0000012910571627), ('deep auto', 1.000001276257573), ('visual saliency', 1.000001276257573), ('clinical electroencephalograms', 1.0000012708537667), ('dissimilarity kernel', 1.000001267951675), ('datapoints', 1.0000012645053606), ('game development', 1.0000012497171886), ('different evaluation', 1.000001232637583), ('conll', 1.000001218615089), ('question answer', 1.0000012184807472), ('power', 1.0000012096842545), ('linear systems', 1.0000012061656933), ('continuous policies', 1.0000012061656933), ('manual labeling', 1.0000012061656933), ('utterances extracted', 1.0000012008897945), ('theoretical analysis', 1.0000011960553439), ('task considered', 1.000001189316735), ('particular feedback', 1.0000011832502982), ('good generalization', 1.0000011792951604), ('minimal parameter', 1.0000011792951604), ('minimal interruption', 1.0000011792951604), ('syntactic information', 1.0000011792951604), ('pair', 1.0000011792153898), ('distal reward changes', 1.0000011728961788), ('fine attention mechanism', 1.0000011728961788), ('numerical values', 1.000001169902713), ('characteristics', 1.0000011653751346), ('linear regions change', 1.0000011630232335), ('question layer', 1.000001162288974), ('feedback policies', 1.0000011481515623), ('healthcare data', 1.0000011481515623), ('goal', 1.0000011478361042), ('parsec', 1.00000114524523), ('vgg network', 1.0000011412852452), ('tool allows', 1.0000011371650102), ('feature set', 1.0000011371650102), ('simulated data', 1.0000011299177263), ('conditioning vector', 1.000001111935419), ('previous satellite images', 1.0000011074885713), ('agents learn', 1.0000011047128041), ('several dialogue domains', 1.0000011042719061), ('edges', 1.0000010985853496), ('such generalization', 1.0000010965142065), ('optimal behavior', 1.0000010965142065), ('legged locomotion', 1.0000010965142065), ('execution', 1.0000010907008419), ('structure', 1.0000010905024508), ('filtering', 1.0000010835660895), ('biomedical question', 1.000001083548043), ('approach deploys', 1.000001083014266), ('such system', 1.0000010814238598), ('sensor based', 1.00000107802206), ('other regression', 1.0000010772443328), ('dqn', 1.0000010762521714), ('more tools', 1.0000010756820314), ('feed', 1.0000010716350611), ('entire environment', 1.0000010712144058), ('dense transformer', 1.0000010694369403), ('correct solutions', 1.0000010635478642), ('skip connection', 1.0000010635478642), ('such generators', 1.0000010635478642), ('flexible activation', 1.0000010635478642), ('navigational instructions', 1.0000010635478642), ('consumer generated', 1.0000010507784913), ('ehr databases', 1.0000010507784913), ('parameter space', 1.000001042158191), ('bits', 1.0000010345951762), ('large language', 1.00000102719788), ('full datasets', 1.00000102719788), ('many benchmarks', 1.00000102719788), ('class', 1.000001025730658), ('transformation', 1.000001016868349), ('statuses comments', 1.0000010062807103), ('photon migration', 1.000001004632545), ('bleu score', 1.000001004632545), ('test target', 1.0000009986245184), ('hierarchical bayesian', 1.0000009933179679), ('discriminative word', 1.0000009933179679), ('fitness', 1.000000989924503), ('further improvement', 1.0000009868627318), ('numerous word', 1.0000009868627318), ('traditional systems', 1.0000009695198475), ('regular autoencoders', 1.0000009681137763), ('positive samples', 1.000000964877755), ('insufficient training', 1.000000963451108), ('lda', 1.0000009609711795), ('holistic face', 1.000000957193027), ('nonlinear transformations', 1.000000957193027), ('prior program', 1.000000957193027), ('internal state', 1.000000957193027), ('noisy time', 1.000000957193027), ('semantic content', 1.0000009381336106), ('highway lstms', 1.0000009296143926), ('types', 1.000000927
796), ('visual sentiment', 1.0000006523936464), ('interactions', 1.0000006511052695), ('critical part', 1.0000006488541755), ('good alignments', 1.0000006481595523), ('additive perturbations', 1.0000006463464606), ('such perturbations', 1.0000006463464606), ('large gtrsim10', 1.0000006463464606), ('adjacent layers', 1.00000064540908), ('natural fuzzification', 1.0000006432517332), ('true labels', 1.0000006427758326), ('explanations', 1.0000006419753455), ('linguistic phrases', 1.0000006381285829), ('spike domain', 1.0000006381285829), ('original vectors', 1.0000006381285829), ('important challenges', 1.0000006381285829), ('topological structures', 1.0000006381285829), ('complex learning', 1.0000006381285829), ('strong baselines', 1.0000006377021093), ('tnns', 1.0000006356606903), ('mel log', 1.0000006336631455), ('base space', 1.0000006333509626), ('way', 1.0000006269235673), ('literature', 1.0000006225348683), ('invariant representations', 1.0000006163186015), ('larger scale', 1.0000006163186015), ('auto', 1.000000601581771), ('symbols pre', 1.000000600444717), ('models geared', 1.000000600444717), ('relevant parts', 1.0000005990336123), ('wmt', 1.000000597659258), ('methods work', 1.0000005956577012), ('eye gaze', 1.0000005955188334), ('depth investigation', 1.0000005955188334), ('specifying', 1.0000005910359033), ('dimension', 1.0000005845111941), ('lower level', 1.0000005840991069), ('spike based', 1.0000005833451335), ('high speed exhibited', 1.0000005815114477), ('molecular biology show', 1.0000005815114477), ('sequence level', 1.0000005809730712), ('label shift', 1.0000005809730712), ('pruning', 1.0000005780890953), ('approximate posterior', 1.0000005768076143), ('large design', 1.0000005761418036), ('chaos', 1.0000005747749656), ('regression', 1.0000005747749656), ('glm t', 1.0000005740756164), ('phrase pairs', 1.0000005740756164), ('stock trading', 1.0000005740756164), ('words characters', 1.0000005740756164), ('term proximity', 1.0000005740756164), ('understanding', 1.0000005735608215), ('proofs', 1.0000005709316329), ('attention ground', 1.0000005706424597), ('classic', 1.0000005698784935), ('glm', 1.0000005681745496), ('multiple', 1.0000005671161047), ('latter case', 1.0000005518431938), ('different sizes', 1.000000548256953), ('small changes', 1.000000548256953), ('further progress', 1.000000548256953), ('statistics', 1.0000005398773706), ('cognitive tasks', 1.000000537840871), ('dictionary elements', 1.000000537840871), ('established knowledge', 1.0000005360430824), ('human judgements', 1.0000005360430824), ('minimal supervision', 1.0000005360430824), ('visual madlibs', 1.0000005323195396), ('practical goal', 1.0000005317737908), ('linguistic interactions', 1.0000005317737908), ('clinical decision', 1.0000005317737908), ('extracting', 1.0000005313753642), ('youtube face', 1.0000005283130025), ('dropout strategy', 1.0000005283130025), ('different modalities', 1.0000005262821703), ('raw sentence', 1.0000005262821703), ('interesting differences', 1.0000005135988081), ('overlapped region', 1.0000005135988081), ('increasing', 1.0000005118130173), ('parts', 1.0000005099277154), ('observations', 1.0000005031198902), ('ancestor network', 1.0000004949173886), ('original space', 1.0000004944065062), ('several', 1.00000049022528), ('viewer opinion', 1.000000486749232), ('stock market', 1.0000004855051923), ('explaining', 1.000000482179445), ('corrects', 1.000000476632296), ('different', 1.0000004713981216), ('acceptability', 1.0000004598199461), ('intention', 1.0000004579534725), ('emergence', 1.
), ('sorted', 1.00000000238185), ('contend', 1.0000000022421345), ('do', 1.0000000021177253), ('understand', 1.0000000017752038), ('exploited', 1.0000000014831896), ('equaled', 1.0000000006268026), ('given', 1.0000000003968856), ('detected', 1.0000000003760816), ('select', 1.000000000363774), ('formulated', 1.000000000250721), ('controlled', 1.000000000250721), ('maximize', 1.0000000001654903), ('desired', 1.000000000043955), ('action related', 1.0), ('explicit delexicalisation', 1.0), ('great benefit', 1.0), ('other candidate', 1.0), ('maximum dialectic', 1.0), ('paper using', 1.0), ('previous hboa', 1.0), ('kyoto university', 1.0), ('drmm yields', 1.0), ('healthcare using', 1.0), ('population', 1.0), ('medical prescriptions', 1.0), ('transferable chemical property', 1.0), ('art cldnn', 1.0), ('understanding analyzing', 1.0), ('high nuisance', 1.0), ('rnns including', 1.0), ('environmental resources', 1.0), ('htrts competition', 1.0), ('album summarization', 1.0), ('several decades', 1.0), ('stale gradients', 1.0), ('full utterances', 1.0), ('several thousands candidate', 1.0), ('activations hurts', 1.0), ('cells connectivity', 1.0), ('salient records', 1.0), ('adult neurogenesis', 1.0), ('deconvolutional operations', 1.0), ('example copynet', 1.0), ('effective imposition', 1.0), ('pictorial scribbles', 1.0), ('lidm shows', 1.0), ('match srnn', 1.0), ('research works', 1.0), ('normal situation', 1.0), ('tightening', 1.0), ('inception score', 1.0), ('toolkit', 1.0), ('continuous outputs', 1.0), ('switchboard benchmark', 1.0), ('many languages character', 1.0), ('biomedicine', 1.0), ('webqa show', 1.0), ('autoencoder mtae', 1.0), ('legged robot', 1.0), ('common approach', 1.0), ('multiple optimization problems', 1.0), ('sequence data', 1.0), ('sensitivity', 1.0), ('second confidence network', 1.0), ('ames', 1.0), ('wikipedia character', 1.0), ('gradient estimate requires', 1.0), ('representative', 1.0), ('core ideas', 1.0), ('learning algorithm', 1.0), ('sentence characteristics', 1.0), ('english tamil', 1.0), ('direct links', 1.0), ('reaches', 1.0), ('conclusive performance', 1.0), ('margin', 1.0), ('multiple timescales', 1.0), ('drug', 1.0), ('audience', 1.0), ('sequenceto', 1.0), ('conventional i', 1.0), ('sensors', 1.0), ('squeezenet', 1.0), ('universal approximation', 1.0), ('bioasq training set', 1.0), ('priors corresponding', 1.0), ('drelus', 1.0), ('motor', 1.0), ('nse', 1.0), ('recommendation domains', 1.0), ('attention combining', 1.0), ('lightweight kalman', 1.0), ('common man made', 1.0), ('competitive multimodal', 1.0), ('interpreter', 1.0), ('fraction', 1.0), ('accumulative elbo', 1.0), ('cv benchmark', 1.0), ('venations', 1.0), ('standard rnn', 1.0), ('many task', 1.0), ('dnns label', 1.0), ('sequence training', 1.0), ('text summarization', 1.0), ('event successor', 1.0), ('particular word', 1.0), ('static frame skip', 1.0), ('mnist usps', 1.0), ('confidence scores', 1.0), ('expressions', 1.0), ('child', 1.0), ('network structure', 1.0), ('new architecture vdcnn', 1.0), ('new hypotheses', 1.0), ('nonparametric density', 1.0), ('novel interpretation', 1.0), ('multiple abstractions', 1.0), ('video compared', 1.0), ('log probability', 1.0), ('inference is', 1.0), ('simplequestions', 1.0), ('synthetic data demonstrates', 1.0), ('scoring approach', 1.0), ('channels', 1.0), ('https pathak22.github', 1.0), ('language inference', 1.0), ('english language tweets', 1.0), ('segmental crf', 1.0), ('fields', 1.0), ('bird', 1.0), ('time dilated', 1.0), ('unified representation', 1.0), ('use vae', 1.0), ('videos requires', 1.0), ('proximity', 1.0), ('text representation', 1.0), ('model benefits', 1.0), ('leverage annotated', 1.0), ('arxiv', 1.0), ('snli corpus', 1.0), ('irnn', 1.0), ('training procedures', 1.0), ('timit corpus', 1.0), ('nonparametric density estimator', 1.0), ('root', 1.0), ('buildings', 1.0), ('monolingual baseline', 1.0), ('complex tasks using', 1.0), ('building', 1.0), ('intermap pooling', 1.0), ('deconvolution', 1.0), ('search based', 1.0), ('gender definition', 1.0), ('important words', 1.0), ('dentate gyrus', 1.0), ('automatic procedures', 1.0), ('standard evidence', 1.0), ('sms messages', 1.0), ('babel database', 1.0), ('painting', 1.0), ('teacher', 1.0), ('natural way', 1.0), ('credit', 1.0), ('generative lan', 1.0), ('mr', 1.0), ('length', 1.0), ('shareboost', 1.0), ('sa', 1.0), ('synthesis unit', 1.0), ('distillation increases', 1.0), ('asr component', 1.0), ('lsa has', 1.0), ('net is', 1.0), ('field approach', 1.0), ('continuous space', 1.0), ('cardiovascular disease', 1.0), ('enhanced sentence', 1.0), ('fsmn', 1.0), ('attention models', 1.0), ('ann helps', 1.0), ('new architecture', 1.0), ('surprising finding', 1.0), ('celeba svhn', 1.0), ('apache', 1.0), ('core model', 1.0), ('explanation', 1.0), ('learning rule', 1.0), ('label bias', 1.0), ('cldnn hmm', 1.0), ('straightforward approach', 1.0), ('systematic methods', 1.0), ('decades', 1.0), ('sampling algorithm', 1.0), ('linguistic processing', 1.0), ('simple kbqa', 1.0), ('lr component', 1.0), ('wheeled robot locomotion', 1.0), ('memory capacity', 1.0), ('other areas', 1.0), ('separate feature analysis', 1.0), ('huge training data', 1.0), ('gae', 1.0), ('rnn encoder', 1.0), ('key transformation', 1.0), ('recurrent loop', 1.0), ('collections', 1.0), ('variability is', 1.0), ('large corpus', 1.0), ('diabetic', 1.0), ('restricted boltzmann machine', 1.0), ('logmelspec features', 1.0), ('simpler subproblems', 1.0), ('findings', 1.0), ('standard machine comprehension', 1.0), ('guidance using', 1.0), ('neural network classifiers', 1.0), ('turn expose', 1.0), ('world models', 1.0), ('list questions', 1.0), ('hochreiter', 1.0), ('emnist', 1.0), ('fidelity', 1.0), ('demanding', 1.0), ('super resolution upsampling', 1.0), ('disembodied', 1.0), ('demonstrated', 1.0), ('timescales', 1.0), ('supports', 1.0), ('original yolov2', 1.0), ('learning based', 1.0), ('preliminary experiment', 1.0), ('conditioning method', 1.0), ('novel response', 1.0), ('scales', 1.0), ('accommodate', 1.0), ('mid', 1.0), ('entire duration', 1.0), ('drift', 1.0), ('new way', 1.0), ('subsume', 1.0), ('mlei', 1.0), ('contains', 1.0), ('novel task clustering', 1.0), ('engineered features', 1.0), ('assigning', 1.0), ('differing length', 1.0), ('conventional transformation', 1.0), ('bayesian treatment', 1.0), ('unsegmented', 1.0), ('gemss', 1.0), ('management', 1.0), ('learnt', 1.0), ('overall classification', 1.0), ('optimizes', 1.0), ('indication', 1.0), ('bring', 1.0), ('rich set', 1.0), ('fewer target classes', 1.0), ('ordering', 1.0), ('popular children', 1.0), ('learning approaches', 1.0), ('larger question', 1.0), ('ablation studies', 1.0), ('generative topic embedding', 1.0), ('charit', 1.0), ('decode', 1.0), ('confer', 1.0), ('particular focus', 1.0), ('explicit attention', 1.0), ('german language', 1.0), ('doing', 1.0), ('associated apis', 1.0), ('dot', 1.0), ('supporting nmt', 1.0), ('atari domain', 1.0), ('normalize', 1.0), ('tighten', 1.0), ('redesign', 1.0), ('preferred', 1.0), ('mammals', 1.0), ('approach links', 1.0), ('frequent', 1.0), ('walk', 1.0), ('superiority', 1.0), ('dimensionalities', 1.0), ('examining', 1.0), ('learning curves', 1.0), ('base cnn', 1.0), ('end machine', 1.0), ('bench', 1.0), ('attains', 1.0), ('schema', 1.0), ('turing machines', 1.0), ('unified method implemented', 1.0), ('manipulating objects', 1.0), ('enormous', 1.0), ('probabilistic model', 1.0), ('sleep', 1.0), ('first model', 1.0), ('adjust', 1.0), ('regions', 1.0), ('object pairs', 1.0), ('newcite', 1.0), ('resources', 1.0), ('disentangled', 1.0), ('tcga database', 1.0), ('natural connection', 1.0), ('certain probability', 1.0), ('increase', 1.0), ('are', 1.0), ('involves', 1.0), ('asymmetric window', 1.0), ('recognise', 1.0), ('imagine', 1.0), ('connects', 1.0), ('stop', 1.0), ('cnn decoder', 1.0), ('generates', 1.0), ('wheeled', 1.0), ('specific requirements', 1.0), ('coco', 1.0), ('mitigate', 1.0), ('e2e kws', 1.0), ('superset', 1.0), ('tensors', 1.0), ('augmented lagrange', 1.0), ('fix', 1.0), ('cnn feature', 1.0), ('impressive', 1.0), ('uniform', 1.0), ('facet', 1.0), ('simplification', 1.0), ('targeted', 1.0), ('based approaches', 1.0), ('versions', 1.0), ('boosting', 1.0), ('ir', 1.0), ('systems lvcsr', 1.0), ('defensive mechanism called', 1.0), ('supervised classification', 1.0), ('lies', 1.0), ('tune', 1.0), ('learning chatbot', 1.0), ('end memory', 1.0), ('network components', 1.0), ('particular class', 1.0), ('exact matching', 1.0), ('query existing', 1.0), ('samdp', 1.0), ('infeasible amount', 1.0), ('deep generator networks', 1.0), ('locate', 1.0), ('descriptive', 1.0), ('deployed machine', 1.0), ('grounded', 1.0), ('sparsity', 1.0), ('faithful', 1.0), ('given training', 1.0), ('annotate', 1.0), ('known entities', 1.0), ('recurrent architecture', 1.0), ('source code', 1.0), ('markup', 1.0), ('language description', 1.0), ('feature processor', 1.0), ('bodily', 1.0), ('first attempts', 1.0), ('suit', 1.0), ('convolutions', 1.0), ('flexible wire', 1.0), ('operate', 1.0), ('fundamental building', 1.0), ('considers', 1.0), ('sensorimotor', 1.0), ('subnetworks', 1.0), ('aligns', 1.0), ('new coarse', 1.0), ('empirical investigation', 1.0), ('simple regularization', 1.0), ('fewer mode collapses', 1.0), ('scoring function', 1.0), ('compositional features', 1.0), ('different levels saved', 1.0), ('alter', 1.0), ('particular target', 1.0), ('northeastern', 1.0), ('labelling', 1.0), ('ignore', 1.0), ('show', 1.0), ('described', 1.0), ('simpler projection', 1.0), ('opposed', 1.0), ('end dialogue', 1.0), ('neural image description', 1.0), ('cause', 1.0), ('jumbled', 1.0), ('given time', 1.0), ('cqa', 1.0), ('cnn baseline', 1.0), ('labelled data', 1.0), ('detecting anomalies', 1.0), ('practice', 1.0), ('large amount', 1.0), ('attractiveness', 1.0), ('unaware', 1.0), ('attending', 1.0), ('rand', 1.0), ('worst performs', 1.0), ('competitive feature', 1.0), ('good predictor', 1.0), ('recent studies', 1.0), ('behaviour trained', 1.0), ('qmdp net', 1.0), ('terpret model', 1.0), ('adding location', 1.0), ('intervention', 1.0), ('neural dependency parser', 1.0), ('baseline dnn', 1.0), ('intuition', 1.0), ('refine', 1.0), ('exist', 1.0), ('communication', 1.0), ('latent edit', 1.0), ('new feature learning', 1.0), ('textit', 1.0), ('important word level', 1.0), ('useful technique', 1.0), ('object localization', 1.0), ('individuals', 1.0), ('statuses', 1.0), ('behavior compensating', 1.0), ('methodology', 1.0), ('favorable', 1.0), ('current frame', 1.0), ('simple game', 1.0), ('compression technique', 1.0), ('auditory', 1.0), ('minimizing edge', 1.0), ('candidate intentions', 1.0), ('solubility dataset', 1.0), ('baseline model', 1.0), ('annotators', 1.0), ('optimization tool', 1.0), ('modality', 1.0), ('small datasets', 1.0), ('world bangla', 1.0), ('rich form', 1.0), ('margins', 1.0), ('complex domain', 1.0), ('robust policies', 1.0), ('proper places', 1.0), ('new model drnet', 1.0), ('more training', 1.0), ('combines', 1.0), ('successful matching', 1.0), ('f1 measure', 1.0), ('gold', 1.0), ('wealthy', 1.0), ('auxiliary task', 1.0), ('legitimate', 1.0), ('intuitive simple', 1.0), ('dedicated', 1.0), ('only word labels', 1.0), ('pretrain', 1.0), ('tied weight', 1.0), ('probabilistic observation', 1.0), ('latter', 1.0), ('brute', 1.0), ('captions', 1.0), ('technique rnn', 1.0), ('complementarity', 1.0), ('scientific journals', 1.0), ('g', 1.0), ('drivers driving', 1.0), ('relate', 1.0), ('remove', 1.0), ('talk', 1.0), ('snail', 1.0), ('messages', 1.0), ('deepmemory', 1.0), ('output results', 1.0), ('risks', 1.0), ('shared', 1.0), ('longer term', 1.0), ('previous words', 1.0), ('represent', 1.0), ('curves', 1.0), ('convincing', 1.0), ('deeper implications', 1.0), ('detailed cost analysis', 1.0), ('maximization', 1.0), ('networks mdrnn', 1.0), ('new task', 1.0), ('focused', 1.0), ('conjunction', 1.0), ('query embeddings', 1.0), ('30s', 1.0), ('visual descriptors', 1.0), ('network conversation', 1.0), ('short term', 1.0), ('metholodogies', 1.0), ('dementia', 1.0), ('multilayer convolutional', 1.0), ('appealing', 1.0), ('overfitting increases', 1.0), ('glass', 1.0), ('detector subnetwork', 1.0), ('swwae', 1.0), ('huge number', 1.0), ('full feed', 1.0), ('denn', 1.0), ('tackle question', 1.0), ('manually', 1.0), ('kullback', 1.0), ('switching', 1.0), ('exploit biases', 1.0), ('improve prediction', 1.0), ('outperformed', 1.0), ('rapidly', 1.0), ('quantified', 1.0), ('valid', 1.0), ('minimum number', 1.0), ('neural relation', 1.0), ('significant impact', 1.0), ('model background', 1.0), ('gan objective', 1.0), ('optimize cnn', 1.0), ('detect stopping', 1.0), ('represent dnns', 1.0), ('acoustic auto', 1.0), ('hybrid speech', 1.0), ('question encodings', 1.0), ('composes', 1.0), ('classify sentences', 1.0), ('perform asr', 1.0), ('provide features', 1.0), ('infeasibility', 1.0), ('neural cache', 1.0), ('random action', 1.0), ('miss modes', 1.0), ('cider reward', 1.0), ('classify images', 1.0), ('visual modalities', 1.0), ('i', 1.0), ('why', 1.0), ('released', 1.0), ('major categories', 1.0), ('attenuate', 1.0), ('quantify generalization', 1.0), ('fuzzification', 1.0), ('model uncertainty', 1.0), ('seeks', 1.0), ('unsuitable', 1.0), ('blind', 1.0), ('speech systems', 1.0), ('differing network', 1.0), ('upper', 1.0), ('unique minimizer', 1.0), ('enhance diagnosis', 1.0), ('widened', 1.0), ('learning sample', 1.0), ('offering', 1.0), ('traditional turing', 1.0), ('predict target', 1.0), ('needed', 1.0), ('single depth', 1.0), ('remain', 1.0), ('isr system', 1.0), ('carry information', 1.0), ('aristotelian', 1.0), ('involving', 1.0), ('interacts', 1.0), ('investigated', 1.0), ('hidden size', 1.0), ('good dataset', 1.0), ('estimate properties', 1.0), ('promising tool', 1.0), ('increasing network', 1.0), ('deep multilayer', 1.0), ('identify spatio', 1.0), ('affordances', 1.0), ('sinogram domain', 1.0), ('mathematically', 1.0), ('tried', 1.0), ('make data', 1.0), ('formal process', 1.0), ('confirmed', 1.0), ('speech enhancement', 1.0), ('smaller learning', 1.0), ('creates', 1.0), ('almost', 1.0), ('detect polarity', 1.0), ('impeded', 1.0), ('challenging benchmarks', 1.0), ('affecting', 1.0), ('realistic generator', 1.0), ('output substrings', 1.0), ('that', 1.0), ('grammars', 1.0), ('existing methods', 1.0), ('train models', 1.0), ('fulfill', 1.0), ('crafted features', 1.0), ('enforcing', 1.0), ('furthermore', 1.0), ('motivations', 1.0), ('uni', 1.0), ('extract edges', 1.0), ('best results', 1.0), ('rewarding', 1.0), ('introduced', 1.0), ('over', 1.0), ('denote', 1.0), ('challenged', 1.0), ('crafted evaluation', 1.0), ('atomic', 1.0), ('perfectly', 1.0), ('explicit supervision', 1.0), ('robustly', 1.0), ('learn sentence', 1.0), ('get state', 1.0), ('highly', 1.0), ('controlled complexity', 1.0), ('potential improvements', 1.0), ('medical condition', 1.0), ('use pop', 1.0), ('suited', 1.0), ('exceeds', 1.0), ('perform navigation', 1.0), ('sequential latent', 1.0), ('mirroring', 1.0), ('visual madlibs task', 1.0), ('consists', 1.0), ('steps', 1.0), ('compact representation', 1.0), ('duration', 1.0), ('enhancing', 1.0), ('creative catalyst', 1.0), ('variational inference based', 1.0), ('hierarchical fashion', 1.0), ('rates', 1.0), ('integrated', 1.0), ('might', 1.0), ('existing dnn', 1.0), ('substantially', 1.0), ('explore novel', 1.0), ('adapting parameters', 1.0), ('da method', 1.0), ('symbolic', 1.0), ('uncover', 1.0), ('good function', 1.0), ('care', 1.0), ('tention', 1.0), ('weakly', 1.0), ('clm', 1.0), ('similarity calculation', 1.0), ('diverse dialogue', 1.0), ('been', 1.0), ('bootstrap', 1.0), ('interpret debug', 1.0), ('100d', 1.0), ('small scale side', 1.0), ('sequence elements', 1.0), ('biomedical qa comprises', 1.0), ('references', 1.0), ('superhuman', 1.0), ('fewer iterations', 1.0), ('purely', 1.0), ('play video', 1.0), ('imitate behaviors', 1.0), ('resurgence', 1.0), ('process tasks', 1.0), ('collecting dialogue', 1.0), ('crcnn', 1.0), ('proposed cnn', 1.0), ('includes', 1.0), ('selection', 1.0), ('last', 1.0), ('imagenet classifier', 1.0), ('model drnet', 1.0), ('including lstm', 1.0), ('truly', 1.0), ('based transfer', 1.0), ('indicate', 1.0), ('register', 1.0), ('handwritten digit classification', 1.0), ('contemporary', 1.0), ('amenable', 1.0), ('robust slu', 1.0), ('versatile', 1.0), ('was', 1.0), ('acquire control', 1.0), ('differentiable memory', 1.0), ('compositional solution', 1.0), ('new setting', 1.0), ('segmental', 1.0), ('predict chemical', 1.0), ('navigate', 1.0), ('abrupt', 1.0), ('generalizing', 1.0), ('biased estimate', 1.0), ('gradient descent method', 1.0), ('realizes', 1.0), ('https visualdialog', 1.0), ('exponentially', 1.0), ('earthquake', 1.0), ('network synthesis', 1.0), ('different models yields', 1.0), ('deep stock', 1.0), ('first set', 1.0), ('kidney loss', 1.0), ('mobile phones', 1.0), ('learning improve', 1.0), ('iterative reconstruction mbir', 1.0), ('computational tractability grows', 1.0), ('constituent', 1.0), ('getting', 1.0), ('abstract concepts', 1.0), ('consequences', 1.0), ('word spellings', 1.0), ('deteriorate', 1.0), ('solo', 1.0), ('merits', 1.0), ('straightforward ensemble method', 1.0), ('heteroscedastic predictions', 1.0), ('induce', 1.0), ('reconsiders', 1.0), ('benn', 1.0), ('implicit features', 1.0), ('gae loss', 1.0), ('embedding layer', 1.0), ('outlier', 1.0), ('favor', 1.0), ('neuroscience literature', 1.0), ('alignment', 1.0), ('invasive', 1.0), ('independent attribute controls', 1.0), ('context based', 1.0), ('randomized models', 1.0), ('perform weight', 1.0), ('proposed algorithm', 1.0), ('maintaining', 1.0), ('mathbf', 1.0), ('oversampling', 1.0), ('large scale side', 1.0), ('high energy', 1.0), ('selective attention', 1.0), ('intermediate stages', 1.0), ('new models', 1.0), ('training objective', 1.0), ('non linearity', 1.0), ('question driven', 1.0), ('aws', 1.0), ('classifier weights', 1.0), ('targeting', 1.0), ('comparably', 1.0), ('multi view networks', 1.0), ('visual context', 1.0), ('fundamental prerequisite', 1.0), ('fuzzy dgp representation', 1.0), ('real life', 1.0), ('encode', 1.0), ('formulates', 1.0), ('datasets show', 1.0), ('new state', 1.0), ('architectures lenet', 1.0), ('tighter region bounds', 1.0), ('many sequence learning', 1.0), ('biomedical question answering', 1.0), ('term detection', 1.0), ('language queries', 1.0), ('ubuntu dialogue dataset', 1.0), ('single classifier scheme', 1.0), ('speech system', 1.0), ('signal processing', 1.0), ('nonparametric', 1.0), ('msrpar task', 1.0), ('special case', 1.0), ('varies', 1.0), ('enforce', 1.0), ('acquire estimates', 1.0), ('small hardware', 1.0), ('technique', 1.0), ('gaps', 1.0), ('discriminator attempts', 1.0), ('unites', 1.0), ('discover patterns', 1.0), ('proposed adaptive', 1.0), ('small perturbation norms', 1.0), ('works done', 1.0), ('recognising', 1.0), ('solvation', 1.0), ('cifar10 benchmark', 1.0), ('admm', 1.0), ('appropriate hardware support', 1.0), ('text line', 1.0), ('xcsf', 1.0), ('improve training', 1.0), ('brute search', 1.0), ('trainable gating', 1.0), ('humans animals', 1.0), ('gain insight', 1.0), ('single label problem', 1.0), ('reusable kernels', 1.0), ('formalism', 1.0), ('prioritizes', 1.0), ('however', 1.0), ('large entailment', 1.0), ('year', 1.0), ('provably', 1.0), ('geometrically', 1.0), ('around', 1.0), ('latent projection', 1.0), ('devised', 1.0), ('extractive qa task', 1.0), ('add capacity', 1.0), ('coherence', 1.0), ('inside', 1.0), ('laboriously', 1.0), ('misspecified', 1.0), ('novel constraint', 1.0), ('exceedingly', 1.0), ('mentioned', 1.0), ('row', 1.0), ('decoders', 1.0), ('proposed arguments', 1.0), ('different locations using', 1.0), ('since', 1.0), ('created', 1.0), ('transparently', 1.0), ('kernel method', 1.0), ('classification task', 1.0), ('temporal attention performs', 1.0), ('assigned', 1.0), ('modified', 1.0), ('randomly', 1.0), ('direct application', 1.0), ('estimated arc', 1.0), ('controlling components', 1.0), ('heterogeneous documents', 1.0), ('drawback', 1.0), ('deep learning opens', 1.0), ('classification object', 1.0), ('distinctive', 1.0), ('theoretical bounds', 1.0), ('gaussian mixture', 1.0), ('leading approaches', 1.0), ('popular datasets', 1.0), ('therefore', 1.0), ('proposed technique', 1.0), ('intended', 1.0), ('specific visibility', 1.0), ('partitioned', 1.0), ('best performance', 1.0), ('proposed pixeldcl', 1.0), ('target behavior', 1.0), ('clinically', 1.0), ('la', 1.0), ('thoroughly', 1.0), ('conditional lstm encoding', 1.0), ('naturally', 1.0), ('benchmark single', 1.0), ('anyone', 1.0), ('hac', 1.0), ('transcript', 1.0), ('embedding vectors', 1.0), ('large open', 1.0), ('sarsa', 1.0), ('semantically', 1.0), ('proposed work', 1.0), ('visual writing', 1.0), ('lr', 1.0), ('neocortical areas', 1.0), ('puts', 1.0), ('rlstm', 1.0), ('names', 1.0), ('considerable bias', 1.0), ('trained system', 1.0), ('resulting kafs', 1.0), ('annotate event', 1.0), ('transfers', 1.0), ('new feature', 1.0), ('minimization problem', 1.0), ('original problem', 1.0), ('browsing', 1.0), ('semantic segmentation demonstrate', 1.0), ('neurons engaged', 1.0), ('backprop', 1.0), ('other hand', 1.0), ('general introduction', 1.0), ('condition selector', 1.0), ('selection mechanism', 1.0), ('occasion', 1.0), ('systematic algorithm', 1.0), ('model perspective', 1.0), ('pipe lined', 1.0), ('cumbersome infrastructure', 1.0), ('combinations', 1.0), ('images using', 1.0), ('trigram language', 1.0), ('conventional gaussian mixture', 1.0), ('completion', 1.0), ('drop', 1.0), ('sms', 1.0), ('usual', 1.0), ('particular prediction', 1.0), ('keyword spotting', 1.0), ('affinity classifier', 1.0), ('human subjects using', 1.0), ('increases', 1.0), ('scientific knowledge', 1.0), ('new design', 1.0), ('generated architectures', 1.0), ('population based', 1.0), ('novel way', 1.0), ('new algorithm called', 1.0), ('single task', 1.0), ('visual display', 1.0), ('concept based', 1.0), ('human face images', 1.0), ('reactive settings mdps', 1.0), ('achieve state', 1.0), ('pan', 1.0), ('different language tasks', 1.0), ('subtract', 1.0), ('robust content', 1.0), ('extraction patterns', 1.0), ('art approaches', 1.0), ('fixed point', 1.0), ('predict advertisement', 1.0), ('made', 1.0), ('new class', 1.0), ('multi function', 1.0), ('semantic similarity word', 1.0), ('decouples', 1.0), ('useful tool', 1.0), ('identify relationships', 1.0), ('with', 1.0), ('staying', 1.0), ('addition induce', 1.0), ('sub goal', 1.0), ('biological system', 1.0), ('crowdsourced', 1.0), ('relatively', 1.0), ('perform parameter', 1.0), ('learn models', 1.0), ('according', 1.0), ('marginalizing', 1.0), ('discards', 1.0), ('starting', 1.0), ('nams', 1.0), ('increasing interest', 1.0), ('token history', 1.0), ('repeated', 1.0), ('examined', 1.0), ('investigation', 1.0), ('explore ways', 1.0), ('contemporary approaches', 1.0), ('miss', 1.0), ('goes', 1.0), ('ce', 1.0), ('ordinary', 1.0), ('makes', 1.0), ('invasive techniques', 1.0), ('drives', 1.0), ('stimulation', 1.0), ('resulting embeddings', 1.0), ('particular image', 1.0), ('appeal', 1.0), ('neural net', 1.0), ('help', 1.0), ('layer depth', 1.0), ('full training', 1.0), ('severe side', 1.0), ('integration', 1.0), ('single probability', 1.0), ('dense vector representations', 1.0), ('multimodal embedding', 1.0), ('produce affinity', 1.0), ('whole sentence is', 1.0), ('explores', 1.0), ('regimen', 1.0), ('trivial', 1.0), ('current performance representation', 1.0), ('high energy physics', 1.0), ('direct influence', 1.0), ('new pairwise', 1.0), ('automatic metrics', 1.0), ('strict', 1.0), ('contribute', 1.0), ('rap', 1.0), ('visually', 1.0), ('coupling', 1.0), ('recurrent feedback', 1.0), ('real drift', 1.0), ('structured input', 1.0), ('varying graph', 1.0), ('ensembles', 1.0), ('annotation', 1.0), ('network technique', 1.0), ('global sequence', 1.0), ('exploit image', 1.0), ('states', 1.0), ('regulatory', 1.0), ('use curriculum', 1.0), ('simple geometrical', 1.0), ('such', 1.0), ('labeled training', 1.0), ('density estimation', 1.0), ('detects', 1.0), ('raw face videos', 1.0), ('read', 1.0), ('shallow pattern matching', 1.0), ('offset', 1.0), ('autonomous information seeking', 1.0), ('new ai', 1.0), ('cnns showing improvements', 1.0), ('learned patterns', 1.0), ('factor model', 1.0), ('penalty', 1.0), ('long standing', 1.0), ('negative pairs resulting', 1.0), ('plain net', 1.0), ('correlate', 1.0), ('randomized', 1.0), ('dog', 1.0), ('accelerometer signal', 1.0), ('neither', 1.0), ('interplay', 1.0), ('alternates', 1.0), ('gersgorin', 1.0), ('semantic descriptor', 1.0), ('documented', 1.0), ('standard schedules', 1.0), ('previously', 1.0), ('first place', 1.0), ('road', 1.0), ('m cnn', 1.0), ('new type', 1.0), ('achieves', 1.0), ('maesn', 1.0), ('extract uncertainty', 1.0), ('away', 1.0), ('ant colony optimization', 1.0), ('imbalanced data', 1.0), ('enhanced network', 1.0), ('traditional classifier', 1.0), ('load', 1.0), ('conventional training', 1.0), ('linear form', 1.0), ('contractive', 1.0), ('connect', 1.0), ('prevents', 1.0), ('gathering information', 1.0), ('visualization method', 1.0), ('analyzed', 1.0), ('fitted neural', 1.0), ('method based', 1.0), ('regular elm', 1.0), ('breed', 1.0), ('intrinsic sparse', 1.0), ('efficient reinforcement', 1.0), ('eyes', 1.0), ('word sequences', 1.0), ('best student', 1.0), ('append skip', 1.0), ('ib', 1.0), ('crowd', 1.0), ('pixelwise', 1.0), ('geometric framework', 1.0), ('new language', 1.0), ('qualitatively', 1.0), ('deconvolutional net', 1.0)]
v9f_words = [('supervised machine learning models', 100), ('long range dependencies', 100), ('neural networks', 100), ('hierarchical deep reinforcement learning', 100), ('distributed database systems', 100), ('machine learning', 100), ('algorithms', 100), ('artificial intelligence', 100), ('constraint programming', 100), ('principal component analysis', 100), ('attention mechanisms', 100), ('natural language processing', 100), ('sequence to sequence learning', 100), ('databases', 100), ('automatic speech recognition', 1.0002653582800498), ('parameter sharing', 1.0001892494069509), ('networks', 1.000127521883045), ('natural language generation', 1.000110181891412), ('residual networks', 1.000073299202453), ('based', 1.0000640867344588), ('task learning', 1.0000401625164312), ('object detection', 1.000037601588907), ('statistical machine translation', 1.0000327429236664), ('images', 1.0000316811532073), ('neural models', 1.0000271874351125), ('processing', 1.0000257805009105), ('feature', 1.0000208896390304), ('recurrent network architectures', 1.0000181102108787), ('visual dialog', 1.000016343295784), ('standard computer vision', 1.0000148596360574), ('image data', 1.000013893163387), ('object', 1.0000129608722064), ('parameters', 1.0000124417240777), ('data sets', 1.000012155531416), ('neural image captioning', 1.0000120734374773), ('conditional language models', 1.0000120734374773), ('computer', 1.0000114423734447), ('application', 1.0000110334274603), ('hierarchical latent variable', 1.0000106803410982), ('electronic health records', 1.0000103844055468), ('work', 1.0000100123216216), ('latent', 1.0000093796585423), ('accuracy', 1.0000093617010413), ('matching', 1.0000092640688736), ('model architecture', 1.0000083963561541), ('imagenet', 1.0000079256824348), ('complex tasks', 1.0000072224970216), ('time', 1.000007029176301), ('prototypical networks', 1.0000067678471485), ('programming', 1.0000067140597781), ('approximation', 1.000006397736636), ('subspaces layers', 1.0000060512087274), ('sparsity', 1.0000055340494656), ('mesh learning', 1.0000052630667202), ('additional data', 1.0000050053754326), ('python code', 1.0000049235143142), ('machine intelligence', 1.0000049235143142), ('experts layer', 1.0000049219933331), ('adaptation layers', 1.000004898594718), ('dependency', 1.000004771101014), ('multimodal', 1.0000046808541996), ('dialogue response', 1.0000045506779836), ('architecture components', 1.0000043442760778), ('dependencies', 1.000004329877446), ('discrete', 1.0000042985254363), ('optimizing', 1.0000042879364033), ('feature engineering', 1.0000041994665712), ('robustness', 1.0000041687546821), ('decision', 1.000004100155786), ('training', 1.000004060252087), ('training iterations', 1.0000039098476208), ('scale learning', 1.0000038022551703), ('logic rules', 1.0000036202287543), ('improve', 1.0000035360107233), ('external memory', 1.0000034811055443), ('data science', 1.0000034440522332), ('processing time', 1.0000033306099716), ('processing videos', 1.0000033306099716), ('model layers', 1.0000032989584302), ('convergence rate', 1.0000031858006118), ('predict', 1.00000317531251), ('approximation errors', 1.0000030409912728), ('network function', 1.0000030409912728), ('mlp learning', 1.000002925698776), ('optimize', 1.0000028980319269), ('dialog state', 1.000002895287262), ('vectors', 1.0000028355140074), ('https', 1.0000028037564077), ('vision', 1.0000027857796019), ('multimodal data', 1.0000027205500526), ('example', 1.000002669967731), ('forward networks', 1.000002617682809), ('target labels', 1.0000026057581586), ('purpose learning', 1.0000024868434139), ('fmri data', 1.000002464058163), ('consistency', 1.000002439772331), ('discrete actions', 1.0000024178635882), ('predicting', 1.0000023835276477), ('relevance', 1.0000023824031485), ('target images', 1.0000023169448928), ('dynamical models', 1.0000022763856815), ('different layers', 1.0000022587733757), ('classes', 1.0000021640526715), ('speech processing', 1.0000021069481928), ('optimum solutions', 1.0000020889428196), ('image question', 1.0000020273264878), ('video sharing', 1.0000020273264878), ('speech engineering', 1.0000020273264878), ('efficiency', 1.0000020037319586), ('overfitting', 1.0000019990505713), ('goal', 1.0000019848066304), ('model initializations', 1.0000018825173165), ('human language communication', 1.0000018574424319), ('several evaluation campaigns', 1.0000018574424319), ('perturbations', 1.000001843368375), ('encoders', 1.000001805833986), ('neuromorphic hardware', 1.0000017781811488), ('functional', 1.0000017585618155), ('human learning', 1.0000017554182383), ('cross', 1.0000017544472377), ('computational efficiency', 1.00000174777958), ('sparse representation', 1.0000017407853798), ('concepts', 1.0000017403618446), ('connections', 1.0000017325796435), ('bits', 1.0000015833267337), ('spectral', 1.000001561624223), ('sentiment', 1.0000015595640377), ('called', 1.000001539437452), ('objective functions', 1.000001491377524), ('complex behaviors', 1.000001491197919), ('robots', 1.0000014772402972), ('successive layers', 1.0000014682768545), ('sentence pair', 1.000001448089929), ('multivariate model', 1.000001448089929), ('class imbalance', 1.0000014476425831), ('sparse windows', 1.0000014340168089), ('standard architectures', 1.0000014340168089), ('previous studies researchers', 1.0000013930815004), ('basic structures', 1.0000013764903077), ('core', 1.0000013724676702), ('runtime', 1.000001365027545), ('unstructured tasks', 1.0000013431568535), ('structured logic', 1.0000013346018535), ('binary features', 1.0000013346018535), ('brain activity', 1.0000013032808417), ('state action', 1.0000013032808417), ('pretraining', 1.0000012633127087), ('interspeech 2015.', 1.0000012619346832), ('similar tasks', 1.0000012559384437), ('texts', 1.0000012523439417), ('small networks', 1.0000012520823505), ('vqa models', 1.0000012155464926), ('dynamical', 1.0000012148345707), ('evaluating', 1.0000011
1.0), ('larger datasets', 1.0), ('adp structure', 1.0), ('skills deciding', 1.0), ('largest skeleton', 1.0), ('feedforward pass', 1.0), ('distinctive feature', 1.0), ('invariant representations', 1.0), ('activities recommendation', 1.0), ('sports channel', 1.0), ('unmixing problems', 1.0), ('powerful learning', 1.0), ('intervention', 1.0), ('negative pairs', 1.0), ('domain data', 1.0), ('regional modeling', 1.0), ('cnn based', 1.0), ('tensor switching', 1.0), ('dropout method', 1.0), ('variable length', 1.0), ('new source', 1.0), ('easier images', 1.0), ('california', 1.0), ('consistent performance', 1.0), ('right answer', 1.0), ('spatial correspondence', 1.0), ('tedious parts', 1.0), ('local interactions', 1.0), ('deep rnns', 1.0), ('text documents', 1.0), ('observed target', 1.0), ('neural questioner', 1.0), ('feudal reinforcement', 1.0), ('consumer generated', 1.0), ('training simplification', 1.0), ('discrete solution', 1.0), ('features optimized', 1.0), ('multiclass model', 1.0), ('constituent', 1.0), ('full supervision', 1.0), ('large scale machine', 1.0), ('specific application', 1.0), ('natural response', 1.0), ('successful machine learning', 1.0), ('stochastic textures', 1.0), ('high quality data', 1.0), ('final performance', 1.0), ('unique advantages', 1.0), ('whole network', 1.0), ('interpretation appears', 1.0), ('unpaired output data', 1.0), ('important parameters', 1.0), ('primary feature', 1.0), ('future context', 1.0), ('arcade game', 1.0), ('multiple research', 1.0), ('manual labeling', 1.0), ('small subset', 1.0), ('smallest number', 1.0), ('adult content', 1.0), ('phonetic knowledge', 1.0), ('input modules', 1.0), ('auditory modality', 1.0), ('abundances', 1.0), ('standard applications', 1.0), ('music sight', 1.0), ('successful submission', 1.0), ('future optimization', 1.0), ('gilr', 1.0), ('new framework', 1.0), ('old cyrillic', 1.0), ('structural target information', 1.0), ('traditional nn', 1.0), ('main endpoints', 1.0), ('popular ann', 1.0), ('radiological dose', 1.0), ('raw video', 1.0), ('sequential short text classification', 1.0), ('mechanisms underlying', 1.0), ('generating images', 1.0), ('movie', 1.0), ('earthquake time', 1.0), ('original problem', 1.0), ('hyperspectral unmixing', 1.0), ('network generates', 1.0), ('genetic programming gsgp', 1.0), ('minimal domain knowledge', 1.0), ('previous crf', 1.0), ('representational power', 1.0), ('linguistic input', 1.0), ('dynamic range resolution', 1.0), ('clinical outcomes', 1.0), ('dense transformer modules', 1.0), ('situ hybridization', 1.0), ('lost peformance', 1.0), ('sequential sentence', 1.0), ('visual systems', 1.0), ('different kinds', 1.0), ('recent renaissance', 1.0), ('maximum likelihood learning', 1.0), ('functional principal component analysis', 1.0), ('previous approaches', 1.0), ('text modeling', 1.0), ('discriminative sentence', 1.0), ('many output symbols', 1.0), ('reduced precision', 1.0), ('networks cnn', 1.0), ('syntactic kernels', 1.0), ('extensive experiments', 1.0), ('mathematical optimization problem', 1.0), ('shot recognition', 1.0), ('las', 1.0), ('networks bnn', 1.0), ('french', 1.0), ('lstm language', 1.0), ('medical corpus', 1.0), ('human infants', 1.0), ('regular deconvolution', 1.0), ('whole history', 1.0), ('program synthesis', 1.0), ('significant variations', 1.0), ('curriculum dropout', 1.0), ('vocal tract', 1.0), ('auxiliary problems', 1.0), ('traditional computer', 1.0), ('dependent plasticity', 1.0), ('mooc data', 1.0), ('neural sequence models', 1.0), ('many pattern recognition', 1.0), ('typhoon eye', 1.0), ('sensory processing', 1.0), ('primate', 1.0), ('same criteria', 1.0), ('continuous control problem', 1.0), ('objective patient', 1.0), ('datasets covering', 1.0), ('chemical properties', 1.0), ('most games', 1.0), ('correct author', 1.0), ('basic aspects', 1.0), ('original cnn', 1.0), ('depth gated', 1.0), ('only cost', 1.0), ('experimental study', 1.0), ('cldnn', 1.0), ('semantic latent representations', 1.0), ('blackout requires', 1.0), ('geometric sense', 1.0), ('human face', 1.0), ('network based', 1.0), ('deep matching', 1.0), ('new examples', 1.0), ('drelu', 1.0), ('logical semantics', 1.0), ('external simulation', 1.0), ('main steps', 1.0), ('fashion', 1.0), ('clustering scheme', 1.0), ('deep lstm', 1.0), ('multi media', 1.0), ('multi evidence filtering', 1.0), ('real world machine', 1.0), ('knowledgebase completion', 1.0), ('current situations', 1.0), ('overall accuracy', 1.0), ('additional information', 1.0), ('conditional model', 1.0), ('nature', 1.0), ('equal parts', 1.0), ('real world images', 1.0), ('stanford sentiment', 1.0), ('molecular level', 1.0), ('complex problems', 1.0), ('more interpretability', 1.0), ('general applicability', 1.0), ('large scale question', 1.0), ('redundant capacity', 1.0), ('neural dynamics', 1.0), ('incremental network', 1.0), ('powerful vqa', 1.0), ('referents', 1.0), ('computational graph', 1.0), ('certain age group', 1.0), ('zeroth order crf', 1.0), ('academic benchmarks', 1.0), ('particular machine', 1.0), ('new images', 1.0), ('french treebank ftb', 1.0), ('network performance', 1.0), ('spatial memory network', 1.0), ('networks involves', 1.0), ('algorithms include', 1.0), ('feature visualization', 1.0), ('difficulty', 1.0), ('structured output problems', 1.0), ('programmable agents', 1.0), ('standard sensitivity', 1.0), ('cumbersome substitute', 1.0), ('natural measures', 1.0), ('partial observability', 1.0), ('diagnostic grading results', 1.0), ('neural enquirer', 1.0), ('tighter region', 1.0), ('fold increase', 1.0), ('text generation', 1.0), ('various hardware', 1.0), ('networks deployed', 1.0), ('artificial neural networks anns', 1.0), ('unrelated categories', 1.0), ('gaussian mixtures', 1.0), ('geometric steps', 1.0), ('geometric information', 1.0), ('diagnostic process', 1.0), ('sparse windows generation', 1.0), ('puzzle piece', 1.0), ('neural network sentence', 1.0), ('medical imaging data', 1.0), ('only attempt', 1.0), ('population', 1.0), ('new architecture design', 1.0), ('gesture recognition', 1.0), ('natural language tasks', 1.0), ('relational rule', 1.0), ('network loses', 1.0), ('bits required', 1.0), ('statistical language', 1.0), ('reasoner has', 1.0), ('tree based', 1.0), ('different time', 1.0), ('traditional aco techniques', 1.0), ('mauna', 1.0), ('enquirer finds', 1.0), ('network decides', 1.0), ('recent advancement', 1.0), ('first recovery', 1.0), ('same time', 1.0), ('neural architecture', 1.0), ('mobile computing', 1.0), ('such extraction algorithms', 1.0), ('networks are', 1.0), ('vocabulary oov words', 1.0), ('available clip', 1.0), ('low signal', 1.0), ('first search', 1.0), ('single shot', 1.0), ('multiple solution', 1.0), ('backpropagation techniques', 1.0), ('less training episodes', 1.0), ('hierarchical levels', 1.0), ('meteoric rise', 1.0), ('common problem', 1.0), ('spectral representations', 1.0), ('concave optimization', 1.0), ('tiered mlp', 1.0), ('models achieve', 1.0), ('algorithmic instability nonrobustness', 1.0), ('deep sentence', 1.0), ('transformation based', 1.0), ('major categories', 1.0), ('tag prediction', 1.0), ('traditional vae', 1.0), ('latent topic', 1.0), ('different hyperparameter choices', 1.0), ('annotation rules', 1.0), ('image collection', 1.0), ('virtual kitti', 1.0), ('generation system', 1.0), ('pluggable models', 1.0), ('dialogue flow', 1.0), ('non context', 1.0), ('network dmtn', 1.0), ('untied neural', 1.0), ('matrix factorization', 1.0), ('lte module', 1.0), ('parameter optimization', 1.0), ('figar', 1.0), ('hub5 switchboard', 1.0), ('independent delay', 1.0), ('single task', 1.0), ('several text', 1.0), ('different input', 1.0), ('cat environment', 1.0), ('random graph', 1.0), ('2013', 1.0), ('neural language model', 1.0), ('separation task', 1.0), ('new formulation', 1.0), ('adversarial loss', 1.0), ('program input', 1.0), ('preliminary dataset', 1.0), ('certain scenario', 1.0), ('unified perspective', 1.0), ('gene modules', 1.0), ('related topics', 1.0), ('square loss', 1.0), ('556k evidences', 1.0), ('such difficulties', 1.0), ('100', 1.0), ('cnn data', 1.0), ('clear advantage', 1.0), ('policy model', 1.0), ('dot product', 1.0), ('distance constraints', 1.0), ('marginal space', 1.0), ('with learned', 1.0), ('computing possibilities', 1.0), ('learning area', 1.0), ('stacking depths', 1.0), ('surgery records', 1.0), ('than', 1.0), ('imbalanced labels', 1.0), ('74.3x', 1.0), ('inter domain', 1.0), ('large learning rates', 1.0), ('events event2sentence', 1.0), ('comprehensible rules', 1.0), ('gcnn model', 1.0), ('limited dataset', 1.0), ('small action', 1.0), ('source sentences', 1.0), ('word order', 1.0), ('public beta', 1.0), ('conversion methods', 1.0), ('source domain', 1.0), ('video action', 1.0), ('2x', 1.0), ('esqns', 1.0), ('acting', 1.0), ('model results', 1.0), ('distance metric', 1.0), ('game quake', 1.0), ('space generator', 1.0), ('critical point analysis', 1.0), ('arbitrary firing', 1.0), ('even in', 1.0), ('bee', 1.0), ('large scale benchmark', 1.0), ('history memories', 1.0), ('absolute values', 1.0), ('discriminative embeddings', 1.0), ('full document', 1.0), ('classifier training', 1.0), ('coherent framework', 1.0), ('effective learning', 1.0), ('translation question', 1.0), ('full batch training', 1.0), ('excellent classification', 1.0), ('1998', 1.0), ('error term', 1.0), ('several machine translation', 1.0), ('problem difficulty', 1.0), ('detailed description', 1.0), ('suggestion accuracy', 1.0), ('unit relu', 1.0), ('affective orientation', 1.0), ('oz', 1.0), ('pca models', 1.0), ('long plateaus', 1.0), ('pixel observations', 1.0), ('modeling performance', 1.0), ('evaluation protocol', 1.0), ('lstm controller', 1.0), ('networks nns', 1.0), ('90.44', 1.0), ('optimization process', 1.0), ('sgd path', 1.0), ('26x', 1.0), ('box classifiers', 1.0), ('neural images', 1.0), ('training corpora', 1.0), ('aged', 1.0), ('depth networks', 1.0), ('frame cnn', 1.0), ('categorical crossentropy', 1.0), ('variable number', 1.0), ('approaching', 1.0), ('stock exchange', 1.0), ('computational savings', 1.0), ('4.84', 1.0), ('discrete maze', 1.0), ('medicinal chemists', 1.0), ('search queries', 1.0), ('continuous space', 1.0), ('entailment model', 1.0), ('92.60', 1.0), ('witnessed', 1.0), ('suffered', 1.0), ('independent fingerspelling', 1.0), ('of fmri', 1.0), ('ai research', 1.0), ('em composition', 1.0), ('action frequency', 1.0), ('associated inference', 1.0), ('unitary initializations', 1.0), ('microblog services', 1.0), ('nonlinear transition', 1.0), ('deci sion', 1.0), ('valid infrastructure', 1.0), ('tremendous success', 1.0), ('autoencoder framework', 1.0), ('difficult image', 1.0), ('from multiple', 1.0), ('limited ability', 1.0), ('monotonic condition', 1.0), ('mountain asia', 1.0), ('precision activations', 1.0), ('unsupervised labeling', 1.0), ('averaging trigger', 1.0), ('method perturb', 1.0), ('motor behaviors', 1.0), ('seemingly', 1.0), ('favours', 1.0), ('narrative outcomes', 1.0), ('object segmentation', 1.0), ('si', 1.0), ('api algorithm', 1.0), ('pendubot swing', 1.0), ('hurts', 1.0), ('multi turn property', 1.0), ('finding architectures', 1.0), ('categorical inference', 1.0), ('specific weaknesses', 1.0), ('image embeddings', 1.0), ('modal task', 1.0), ('analytic activation', 1.0), ('emergent organization', 1.0), ('sequence generators', 1.0), ('kit htk', 1.0), ('german', 1.0), ('accuracy rates', 1.0), ('translation model', 1.0), ('19.1', 1.0), ('t type', 1.0), ('novel vector', 1.0), ('wider class', 1.0), ('common set', 1.0), ('exploration strategies', 1.0), ('global context', 1.0), ('tuning size', 1.0), ('deep search', 1.0), ('english tamil language', 1.0), ('collaborative recurrent autoencoder', 1.0), ('important positions', 1.0), ('potential grammar', 1.0), ('utility technologies', 1.0), ('variable term', 1.0), ('complex rnns', 1.0), ('code units', 1.0), ('free learning', 1.0), ('many examples', 1.0), ('constant number', 1.0), ('great advances', 1.0), ('important applications', 1.0), ('algorithm dqn', 1.0), ('51', 1.0), ('intentions', 1.0), ('eda framework', 1.0), ('learning tasks', 1.0), ('commonplace', 1.0), ('zsc', 1.0), ('multispectral images', 1.0), ('modern attempt', 1.0), ('earlier results', 1.0), ('lstm units', 1.0), ('streaking', 1.0), ('several years', 1.0), ('fundamental machine', 1.0), ('sample generations', 1.0), ('box system', 1.0), ('set theory', 1.0), ('dialogue assistants', 1.0), ('network need', 1.0), ('linear model glm', 1.0), ('same family', 1.0), ('free agents', 1.0), ('to new', 1.0), ('mobile phones', 1.0), ('original ones', 1.0), ('cross layer convolution', 1.0), ('structural information', 1.0), ('unsupervised text', 1.0), ('strong network', 1.0), ('1901', 1.0), ('rademacher complexity', 1.0), ('longer history', 1.0), ('descriptive power', 1.0), ('storage power', 1.0), ('gradient descent schemes', 1.0), ('coco dataset', 1.0), ('efficient representation', 1.0), ('individual problem', 1.0), ('noisy signals', 1.0), ('many time', 1.0), ('neucube connectivity', 1.0), ('nets rmnn', 1.0), ('fpga implementation', 1.0), ('large softmax output layers', 1.0), ('mat', 1.0), ('gender blood', 1.0), ('circumstances', 1.0), ('channels synapses', 1.0), ('recurrent sequence generators', 1.0), ('voxel pattern', 1.0), ('datasets pedestrian', 1.0), ('simpler network', 1.0), ('upper case', 1.0), ('networks rnn', 1.0), ('nonlinear function', 1.0), ('stores neuron', 1.0), ('workers', 1.0), ('sufficient amounts', 1.0), ('program structure', 1.0), ('discrete stochastic', 1.0), ('integral', 1.0), ('webquestions', 1.0), ('language sentences', 1.0), ('extrinsic labels', 1.0), ('modeling sentiment', 1.0), ('level data', 1.0), ('new direction', 1.0), ('3d object', 1.0), ('tractable learning sampling', 1.0), ('deep coral', 1.0), ('squishednets possess', 1.0), ('demo video', 1.0), ('phonetic features', 1.0), ('specifically', 1.0), ('complete lack', 1.0), ('satellite imagery', 1.0), ('tuning scheme', 1.0), ('qualitative language', 1.0), ('on classification', 1.0), ('party developers', 1.0), ('class probabilities', 1.0), ('minimum features engineering', 1.0), ('internal connections', 1.0), ('baseline rnnsearch model', 1.0), ('art error', 1.0), ('model rnnmorph', 1.0), ('weaker adversaries', 1.0), ('improved pattern', 1.0), ('weathergov', 1.0), ('shape retrieval', 1.0), ('widened', 1.0), ('map variants', 1.0), ('learner texts', 1.0), ('tomography ct', 1.0), ('ale', 1.0), ('sample efficiency', 1.0), ('generation model', 1.0), ('assistant alexa', 1.0), ('squares algorithm', 1.0), ('high precision', 1.0), ('considerable bias', 1.0), ('compression algorithm', 1.0), ('scale coco', 1.0), ('heterogeneous text', 1.0), ('use vae', 1.0), ('hierarchical bayesian models', 1.0), ('multiple visual classification tasks', 1.0), ('better parameterization', 1.0), ('heterogeneous text networks', 1.0), ('small image', 1.0), ('kn', 1.0), ('gradient calculation', 1.0), ('impede', 1.0), ('visualisation technique', 1.0), ('mono clock', 1.0), ('small perturbation norms', 1.0), ('inception imagenet', 1.0), ('global mininum', 1.0), ('current computing', 1.0), ('small convolutions', 1.0), ('various architectures', 1.0), ('many hyperparameters', 1.0), ('improved strength', 1.0), ('affordance exploration', 1.0), ('proposed', 1.0), ('huge area', 1.0), ('kim', 1.0), ('prediction time', 1.0), ('database event', 1.0), ('machine choreography', 1.0), ('output sequence', 1.0), ('greedy augmentation', 1.0), ('network dnn', 1.0), ('best compression rates', 1.0), ('semantic embeddings', 1.0), ('dynamics model', 1.0), ('syntactical programs', 1.0), ('warm restart learning', 1.0), ('database tokens', 1.0), ('simple algorithms', 1.0), ('third party developers', 1.0), ('12.7', 1.0), ('masking functions', 1.0), ('layer inputs', 1.0), ('similarity matrix', 1.0), ('document sentences', 1.0), ('mid level', 1.0), ('activity doesn', 1.0), ('variational auto encoders', 1.0), ('karl pearson', 1.0), ('prediction methods', 1.0), ('provide insights', 1.0), ('framework termed', 1.0), ('neural network algorithm', 1.0), ('estimated power', 1.0), ('benchmarked tasks', 1.0), ('variable neural network', 1.0), ('the bayesian', 1.0), ('cost incurred', 1.0), ('sizes are', 1.0), ('increasing parameters', 1.0), ('generate predictions', 1.0), ('architecture referred', 1.0), ('codes capture', 1.0), ('a subset', 1.0), ('main thinking modes', 1.0), ('high level feature', 1.0), ('process based', 1.0), ('improve prediction', 1.0), ('standing challenge', 1.0), ('encourage sparsity', 1.0), ('selected lines', 1.0), ('learn language', 1.0), ('different model predictions', 1.0), ('embeddings using', 1.0), ('modelling summarises', 1.0), ('that includes', 1.0), ('agents communicate', 1.0), ('rnn clm', 1.0), ('effectiveness targeting', 1.0), ('simulations using', 1.0), ('image classifies', 1.0), ('unsupervised labeling tasks', 1.0), ('techniques require', 1.0), ('datasets show', 1.0), ('have advantages', 1.0), ('experiments lead', 1.0), ('expected payoff', 1.0), ('watching objects', 1.0), ('network uses', 1.0), ('appropriate error handling', 1.0), ('scheme allowing', 1.0), ('novel unsupervised', 1.0), ('resulting architecture', 1.0), ('scanner developed', 1.0), ('image embedding', 1.0), ('model agree', 1.0), ('error oriented', 1.0), ('provide point', 1.0), ('uniform sub network', 1.0), ('benchmark indicate', 1.0), ('of painter', 1.0), ('on runtime', 1.0), ('generalised bilinear', 1.0), ('embedding comes', 1.0), ('gans sidestep', 1.0), ('dataset suggesting', 1.0), ('makes robustness', 1.0), ('person performing', 1.0), ('dataset based', 1.0), ('alternating direction', 1.0), ('specific discriminative models', 1.0), ('learning time', 1.0), ('neural networks dcns', 1.0), ('nest starts', 1.0), ('systems seek', 1.0), ('ehr derived', 1.0), ('blending physics', 1.0), ('simulating dmms', 1.0), ('tasks using', 1.0), ('development involves', 1.0), ('identify relationships', 1.0), ('optimal hyperparameter values', 1.0), ('way learn', 1.0), ('detected keywords', 1.0), ('propose object', 1.0), ('approach outperforms', 1.0), ('samples requires', 1.0), ('producing exploration', 1.0), ('system using', 1.0), ('input mathbf', 1.0), ('embedding models', 1.0), ('with natural', 1.0), ('planner trained', 1.0), ('o is', 1.0), ('model involving', 1.0), ('inexpensive kernel expansion', 1.0), ('artificial intelligence methods', 1.0), ('bands suffer', 1.0), ('oriented databases', 1.0), ('model needs', 1.0), ('lvm provides', 1.0), ('programs become', 1.0), ('giving instance', 1.0), ('growing field', 1.0), ('ending sequences', 1.0), ('deep learning practitioners', 1.0), ('increase accuracy', 1.0), ('actions guiding', 1.0), ('reduce uninterpretability', 1.0), ('data acquired', 1.0), ('learned word', 1.0), ('actions chaining', 1.0), ('functionality helps', 1.0), ('cnn alleviate', 1.0), ('self play', 1.0), ('answer questions', 1.0), ('acoustic model training', 1.0), ('imposing function', 1.0), ('embedding method', 1.0), ('synthesis given', 1.0), ('points providing', 1.0), ('property converts', 1.0), ('multiple clip arts', 1.0), ('specific annotations e', 1.0), ('on other', 1.0), ('examples are', 1.0), ('modeling leads', 1.0), ('interval based', 1.0), ('work demonstrates', 1.0), ('use backpropagation', 1.0), ('hypothesis proposes', 1.0), ('optimize sentence', 1.0), ('lstms remain', 1.0), ('algorithm known', 1.0), ('experiment shows', 1.0), ('working memory', 1.0), ('based attack', 1.0), ('ranking with', 1.0), ('crafted feature', 1.0), ('cascades exhibit', 1.0), ('work improves', 1.0), ('narrative requires', 1.0), ('studying gan', 1.0), ('deep intelligence framework', 1.0), ('holistic attribute discriminators', 1.0), ('bring insights', 1.0), ('of generative', 1.0), ('null space signals', 1.0), ('present results', 1.0), ('identifying properties', 1.0), ('to sequence', 1.0), ('underlying data dimensions', 1.0), ('cross selling', 1.0), ('ofthe art systems', 1.0), ('kb aiming', 1.0), ('visual gmm hmm', 1.0), ('labeled dataset', 1.0), ('perplexity optimizing', 1.0), ('minimum showing', 1.0), ('is end', 1.0), ('loss used', 1.0), ('methods obtaining', 1.0), ('interpret debug', 1.0), ('denoising auto', 1.0), ('residual learning approach', 1.0), ('least squares algorithm', 1.0), ('for many', 1.0), ('introspection revealed', 1.0), ('labeled data', 1.0), ('ordered image', 1.0), ('vectors representing', 1.0), ('report experiments', 1.0), ('dictionaries provide', 1.0), ('system is', 1.0), ('predicting drug', 1.0), ('functions is', 1.0), ('end sequence', 1.0), ('module embedded', 1.0), ('system developed', 1.0), ('models facing', 1.0), ('tuning ann', 1.0), ('variation bootstrapped', 1.0), ('generic pcg framework', 1.0), ('neural network snn', 1.0), ('successful submission systems', 1.0), ('in sentiment', 1.0), ('approach named', 1.0), ('go systems', 1.0), ('constrained feed', 1.0), ('key space mathbb', 1.0), ('nonparametric regression datasets', 1.0), ('method known', 1.0), ('estimate similarity', 1.0), ('elaborate planning strategies', 1.0), ('involve tool', 1.0), ('modern recurrent', 1.0), ('predicted answer', 1.0), ('quality estimated', 1.0), ('preserve speaker', 1.0), ('grained information', 1.0), ('to complex', 1.0), ('lists employing', 1.0), ('estimation using', 1.0), ('harms humans', 1.0), ('unit has', 1.0), ('automating data', 1.0), ('on recurrent', 1.0), ('outline extensions', 1.0), ('embedding learning', 1.0), ('patch centered', 1.0), ('objects mentioned', 1.0), ('training targets', 1.0), ('of downstream', 1.0), ('accuracy making', 1.0), ('miss modes', 1.0), ('tanh based', 1.0), ('extract drug', 1.0), ('backpropagation inspired', 1.0), ('gradients aren', 1.0), ('cnn allow', 1.0), ('correlates including', 1.0), ('rnn encodes', 1.0), ('known image', 1.0), ('identifying statements', 1.0), ('abstractive sentence summarisation', 1.0), ('previous dialog utterances', 1.0), ('attentive inference components', 1.0), ('spatial attention architecture', 1.0), ('given task', 1.0), ('interpretability identifying', 1.0), ('inference enabling', 1.0), ('learning emphasizes', 1.0), ('of peak', 1.0), ('ordering performance', 1.0), ('mapping defined', 1.0), ('such bigram embeddings', 1.0), ('resulting lrp', 1.0), ('technique produces', 1.0), ('paper articulates', 1.0), ('mini batch discrimination', 1.0), ('width tradeoffs', 1.0), ('comprehensive overview', 1.0), ('local word collocation', 1.0), ('models bag', 1.0), ('co operation', 1.0), ('inductive decision tree', 1.0), ('provide maps', 1.0), ('runtime performance', 1.0), ('translation systems', 1.0), ('successor generation', 1.0), ('single typhoon', 1.0), ('different evaluation methods', 1.0), ('natural language inference', 1.0), ('convolutional spike', 1.0), ('units lstm', 1.0), ('public beta test', 1.0), ('reasoning systems', 1.0), ('patients', 1.0), ('detect polarity', 1.0), ('appealing features', 1.0), ('platform engaging', 1.0), ('ive bayes', 1.0), ('agent trained', 1.0), ('existing ann', 1.0), ('box understanding', 1.0), ('clustering methods', 1.0), ('dependency information', 1.0), ('continuous functions', 1.0), ('next event', 1.0), ('learning applied', 1.0), ('current approaches', 1.0), ('minimization algorithm', 1.0), ('results including', 1.0), ('lookup table', 1.0), ('accurate tools', 1.0), ('human eyes', 1.0), ('recognition challenge', 1.0), ('weights increase', 1.0), ('awa', 1.0), ('time inducing', 1.0), ('infer object', 1.0), ('major building', 1.0), ('more resource', 1.0), ('techniques exhibit', 1.0), ('dialogue strategies', 1.0), ('legged robot', 1.0), ('inferring models', 1.0), ('meaningful configuration', 1.0), ('coral correlation', 1.0), ('simulated robotics', 1.0), ('specify subroutine', 1.0), ('specialists', 1.0), ('attain invariance', 1.0), ('determining factors', 1.0), ('hts', 1.0), ('system responses', 1.0), ('successfully', 1.0), ('resort', 1.0), ('similarity network', 1.0), ('recursive neural language architecture', 1.0), ('higher level data', 1.0), ('mcdonnell', 1.0), ('study', 1.0), ('resulting sparse', 1.0), ('typical experiences', 1.0), ('z drawn', 1.0), ('babel corpus', 1.0), ('smooth encoder', 1.0), ('networks incur', 1.0), ('space complexity', 1.0), ('deep learning taxonomy', 1.0), ('black box priors', 1.0), ('scheme combined', 1.0), ('saw', 1.0), ('recognition model', 1.0), ('former', 1.0), ('group size', 1.0), ('at multiple', 1.0), ('issue require', 1.0), ('overcome abc', 1.0), ('importance suggesting', 1.0), ('new denoising scheme', 1.0), ('fge', 1.0), ('correspondence required', 1.0), ('order language', 1.0), ('organized agent', 1.0), ('recognition examples', 1.0), ('on nonnegative', 1.0), ('network language', 1.0), ('biomedical word embeddings', 1.0), ('published result', 1.0), ('future events', 1.0), ('letters', 1.0), ('good generalization properties', 1.0), ('multiagent play', 1.0), ('problems zsc', 1.0), ('european medicines agency', 1.0), ('study reveals', 1.0), ('based recognition', 1.0), ('prior distributions', 1.0), ('specific attention', 1.0), ('class has', 1.0), ('global term frequency', 1.0), ('page ranking', 1.0), ('nurture debate', 1.0), ('term detection', 1.0), ('existing form', 1.0), ('contrastive divergence cd', 1.0), ('estimation bbse', 1.0), ('rectified linear unit relu', 1.0), ('dependent data representations', 1.0), ('growing synergies', 1.0), ('efficient strategy', 1.0), ('increased accuracy', 1.0), ('randomized interventions', 1.0), ('ones including', 1.0), ('simple word hypotheses', 1.0), ('deep generator network', 1.0), ('developing representations', 1.0), ('songs', 1.0), ('neural turing', 1.0), ('comprehension models', 1.0), ('summarization tasks', 1.0), ('desirable properties', 1.0), ('test cbt', 1.0), ('investigate redundancies', 1.0), ('uncorrelation assumption', 1.0), ('biochemical', 1.0), ('real world stochastic', 1.0), ('tasks include', 1.0), ('good properties', 1.0), ('weight dropped', 1.0), ('high levels', 1.0), ('neural text', 1.0), ('history vector', 1.0), ('several types', 1.0), ('efficient usage', 1.0), ('1d', 1.0), ('study data', 1.0), ('parametric feature construction', 1.0), ('distillation increases', 1.0), ('gigaword dataset', 1.0), ('facilitate research', 1.0), ('scheme lis', 1.0), ('stacked qrnns', 1.0), ('study schemes', 1.0), ('perform asr', 1.0), ('things being', 1.0), ('architecture vdcnn', 1.0), ('mobile applications', 1.0), ('important features', 1.0), ('processing field', 1.0), ('modern system', 1.0), ('independent speaker verification', 1.0), ('inducing regularization', 1.0), ('discrete structures', 1.0), ('data behave', 1.0), ('additional hints', 1.0), ('called dictionary', 1.0), ('birth rate', 1.0), ('deep neural networks dnns', 1.0), ('multiple research disciplines', 1.0), ('inference task', 1.0), ('optimal architecture', 1.0), ('gene ontology', 1.0), ('virtual environment', 1.0), ('probabilistic programming language', 1.0), ('classification performance', 1.0), ('proximity based', 1.0), ('neurogenesis inspired', 1.0), ('ideal task', 1.0), ('relation detector', 1.0), ('triplet accuracy', 1.0), ('1000', 1.0), ('neural network training', 1.0), ('path level', 1.0), ('dybm', 1.0), ('system constructed', 1.0), ('studies rfns', 1.0), ('huge variety', 1.0), ('spatial arrangement', 1.0), ('synthetic gan', 1.0), ('authors knowledge', 1.0), ('particle filter', 1.0), ('exploit image', 1.0), ('adaptive regularization scheme', 1.0), ('cheaper model', 1.0), ('sensor space', 1.0), ('future satellite', 1.0), ('rank minimization', 1.0), ('people', 1.0), ('deep mlps', 1.0), ('intriguing property', 1.0), ('raw inputs', 1.0), ('better learning', 1.0), ('first cdm separates', 1.0), ('performs transfer', 1.0), ('judgements', 1.0), ('competitive scenarios', 1.0), ('informative gradients', 1.0), ('a prepossessing', 1.0), ('achieves better', 1.0), ('the step', 1.0), ('new larger', 1.0), ('such object', 1.0), ('encoders late', 1.0), ('class independent', 1.0), ('large supervised', 1.0), ('unneeded hidden', 1.0), ('case conjugate', 1.0), ('the case', 1.0), ('chain conditional', 1.0), ('network dagan', 1.0), ('this vector', 1.0), ('the issues', 1.0), ('this approach', 1.0), ('this pressure', 1.0), ('an slu', 1.0), ('the hmm', 1.0), ('the one', 1.0), ('temporal raw', 1.0), ('the children', 1.0), ('the derivatives', 1.0), ('every layer', 1.0), ('a tool', 1.0), ('that backpropagation', 1.0), ('a 3d', 1.0), ('a seed', 1.0), ('novel textual', 1.0), ('more challenging', 1.0), ('problem dependent', 1.0), ('an element', 1.0), ('parsers due', 1.0), ('by training', 1.0), ('each weight', 1.0), ('the challenge', 1.0), ('a speech', 1.0), ('human visual', 1.0), ('future real', 1.0), ('a prerequisite', 1.0), ('several public', 1.0), ('this contribution', 1.0), ('each input', 1.0), ('the text', 1.0), ('on overlapped region', 1.0), ('the evaluations', 1.0), ('experiments qmdp', 1.0), ('a learning', 1.0), ('uncertain semantic', 1.0), ('an observation', 1.0), ('a sparql', 1.0), ('all methods', 1.0), ('any multimodal', 1.0), ('image multiple', 1.0), ('a direction', 1.0), ('irrelevant underlying', 1.0), ('these states', 1.0), ('performance less', 1.0), ('natural adversarial', 1.0), ('the transition', 1.0), ('novel extreme', 1.0), ('this failure', 1.0), ('auxiliary supervised discrimination tasks', 1.0), ('the stability', 1.0), ('devices such', 1.0), ('the constraints', 1.0), ('the complementarity', 1.0), ('all subjects', 1.0), ('an asr', 1.0), ('limited real', 1.0), ('each dataset', 1.0), ('depths larger', 1.0), ('bayesian logistic', 1.0), ('network acoustic', 1.0), ('standard deep learning methods', 1.0), ('linear discriminant', 1.0), ('a neuro', 1.0), ('dependent recurrent', 1.0), ('achieve comparable', 1.0), ('data hungry', 1.0), ('advanced chemical', 1.0), ('the loop', 1.0), ('some example', 1.0), ('the photo', 1.0), ('baseline full', 1.0), ('the word', 1.0), ('finite dimensional', 1.0), ('a program', 1.0), ('the pnet', 1.0), ('spatial variational', 1.0), ('polynomial neural', 1.0), ('interpretable traditional', 1.0), ('different auxiliary', 1.0), ('the paragraph', 1.0), ('non local', 1.0), ('random initial', 1.0), ('recent incremental', 1.0), ('decade many', 1.0), ('of multivariate', 1.0), ('constant unlearned', 1.0), ('theory artificial', 1.0), ('a transition', 1.0), ('the textit', 1.0), ('compare structural', 1.0), ('the reduction', 1.0), ('spectrum by', 1.0), ('each neuron', 1.0), ('times less', 1.0), ('the source', 1.0), ('the robustness', 1.0), ('generation lbpcg', 1.0), ('many neural', 1.0), ('the model', 1.0), ('the transferability', 1.0), ('noise robust', 1.0), ('non chaotic', 1.0), ('the markov', 1.0), ('that hindsight', 1.0), ('the ami', 1.0), ('straightforward recurrent', 1.0), ('the part', 1.0), ('the iris', 1.0), ('retrieval natural', 1.0), ('wise greedy', 1.0), ('into complex', 1.0), ('a computer', 1.0), ('a toy', 1.0), ('same abstract', 1.0), ('no information', 1.0), ('non trivial', 1.0), ('the aurora', 1.0), ('the correction', 1.0), ('the overfit', 1.0), ('correlation neural', 1.0), ('like recurrent highway', 1.0), ('semantic facial feature recognition', 1.0), ('the clusters', 1.0), ('for specific', 1.0), ('activations such', 1.0), ('multi stream', 1.0), ('the theory', 1.0), ('the dearth', 1.0), ('artificial visual', 1.0), ('the atis', 1.0), ('the reader', 1.0), ('convolutional artificial', 1.0), ('with introspective', 1.0), ('a model', 1.0), ('a pseudo', 1.0), ('no classifiers', 1.0), ('for natural', 1.0), ('these datasets', 1.0), ('the reconstruction', 1.0), ('several new', 1.0), ('algorithm sparse', 1.0), ('initializations conducive', 1.0), ('pixel wise', 1.0), ('separate explicit', 1.0), ('the difficulties', 1.0), ('on network', 1.0), ('a cnn', 1.0), ('time speedups', 1.0), ('modified samples', 1.0), ('linear classification', 1.0), ('architectures suitable', 1.0), ('any mapping', 1.0), ('times fewer', 1.0), ('mean field inference', 1.0), ('chinese sentence', 1.0), ('elm e', 1.0), ('to previous', 1.0), ('gps records', 1.0), ('hidden weights', 1.0), ('technical ingredients', 1.0), ('many high risk tasks', 1.0), ('such holistic', 1.0), ('lexical domains', 1.0), ('la', 1.0), ('perform speech', 1.0), ('the advancements', 1.0), ('encoders vae', 1.0), ('english wmt', 1.0), ('89', 1.0), ('lowest environmental', 1.0), ('the salient', 1.0), ('previous move', 1.0), ('previous timestep', 1.0), ('diverse feature', 1.0), ('previous move prediction', 1.0), ('use mel', 1.0), ('given data', 1.0), ('word descriptions', 1.0), ('comprehensive review', 1.0), ('phoneme posteriors', 1.0), ('the labeling', 1.0), ('proposes attacks', 1.0), ('result methods', 1.0), ('query tables', 1.0), ('same dataset', 1.0), ('network classifier', 1.0), ('psychophysical behavior', 1.0), ('real world pattern', 1.0), ('novel weight', 1.0), ('new basic', 1.0), ('swarm optimization', 1.0), ('latter role', 1.0), ('different image classification', 1.0), ('uses cnn', 1.0), ('labeling models', 1.0), ('evaluation set', 1.0), ('regularization differ', 1.0), ('symbolic executor', 1.0), ('policy networks', 1.0), ('learnable transformations', 1.0), ('present ablation', 1.0), ('problems demonstrating', 1.0), ('aware multi', 1.0), ('points increase', 1.0), ('distributional representations', 1.0), ('whole image network', 1.0), ('natural result', 1.0), ('random sparse topology', 1.0), ('forget', 1.0), ('free tracking solution', 1.0), ('at different', 1.0), ('different hierarchies', 1.0), ('strong network performance', 1.0), ('discover patterns', 1.0), ('technique rnn', 1.0), ('any independence', 1.0), ('extract bottleneck', 1.0), ('image tagging', 1.0), ('matrices are', 1.0), ('way communication', 1.0), ('both modalities', 1.0), ('sized class vocabularies', 1.0), ('various numbers', 1.0), ('scratch using', 1.0), ('level granularity', 1.0), ('log mel', 1.0), ('importance maps', 1.0), ('ing imaging', 1.0), ('am rnn', 1.0), ('single framework', 1.0), ('describing multimedia', 1.0), ('the autoencoder', 1.0), ('process consists', 1.0), ('better perplexity', 1.0), ('bandit problems', 1.0), ('algorithm solves', 1.0), ('the approach', 1.0), ('wide layer', 1.0), ('value problems', 1.0), ('slu approach', 1.0), ('good promise', 1.0), ('social biases', 1.0), ('energy stationary', 1.0), ('policy network', 1.0), ('run time', 1.0), ('play algorithm', 1.0), ('the formulation', 1.0), ('have limitations', 1.0), ('these eegs', 1.0), ('knowledge enables', 1.0), ('questioner owing', 1.0), ('are state', 1.0), ('movie summary', 1.0), ('pair examples', 1.0), ('networks specialized', 1.0), ('groups affects', 1.0), ('the flexibility', 1.0), ('modern optimization techniques', 1.0), ('sensitive model', 1.0), ('does consistency', 1.0), ('positive experimental', 1.0), ('teacher model', 1.0), ('classifier predicts', 1.0), ('such decision', 1.0), ('manning', 1.0), ('dependencies such', 1.0), ('policy pso', 1.0), ('powerful ensemble', 1.0), ('demonstrate improvements', 1.0), ('model information', 1.0), ('cognitive psychology view', 1.0), ('key contribution', 1.0), ('famous k', 1.0), ('practical advice', 1.0), ('names control', 1.0), ('comparative algorithms', 1.0), ('the magnitude', 1.0), ('own communication protocol', 1.0), ('subsymbolic vector representations', 1.0), ('core lies', 1.0), ('method combining', 1.0), ('gaussian covariance matrix', 1.0), ('undesirable biases e', 1.0), ('variables relative', 1.0), ('specific challenges', 1.0), ('one', 1.0), ('recognition transcription', 1.0), ('adaptive feature', 1.0), ('architectures called', 1.0), ('perceptron mlp', 1.0), ('stimulating perspectives', 1.0), ('concentration', 1.0), ('maximization unsupervised', 1.0), ('low curvature', 1.0), ('human action analysis', 1.0), ('method akin', 1.0), ('go datasets', 1.0), ('pre trained', 1.0), ('temporal common', 1.0), ('differences remain', 1.0), ('a grow', 1.0), ('produce results', 1.0), ('essential properties', 1.0), ('deep vgg', 1.0), ('2010', 1.0), ('intermediate hidden', 1.0), ('two multimodal', 1.0), ('mapping algorithm', 1.0), ('reported difficulties', 1.0), ('reason deep', 1.0), ('single pass performance', 1.0), ('multimodal vector', 1.0), ('conclusive performance hierarchy', 1.0), ('a viewpoint', 1.0), ('eventual functions', 1.0), ('high level abstractions', 1.0), ('device scenarios', 1.0), ('continuous action spaces', 1.0), ('the scan', 1.0), ('novel complex', 1.0), ('resulting model', 1.0), ('episodic semantic', 1.0), ('model ibowimg', 1.0), ('dsn method', 1.0), ('large language', 1.0), ('continuous markov', 1.0), ('proposed highway', 1.0), ('clinical variables', 1.0), ('different policy', 1.0), ('attributes highlighted', 1.0), ('bias problem', 1.0), ('diverse images', 1.0), ('existing implementations', 1.0), ('conducting experiments', 1.0), ('different ways', 1.0), ('models required', 1.0), ('wise appropriate', 1.0), ('the trade', 1.0), ('discrete latent variable', 1.0), ('compared with', 1.0), ('hardware implementations', 1.0), ('the order', 1.0), ('network sentence', 1.0), ('which datasets', 1.0), ('hurdle', 1.0), ('images demonstrate', 1.0), ('databases store', 1.0), ('basic encoder', 1.0), ('prescribed tests', 1.0), ('network dynamics', 1.0), ('rare word problem', 1.0), ('65', 1.0), ('standard knowledge distillation', 1.0), ('networks exhibit', 1.0), ('unlimited amount', 1.0), ('a copy', 1.0), ('perturbations reveals', 1.0), ('new active', 1.0), ('high triplet accuracy', 1.0), ('all labels', 1.0), ('generalization behaviors', 1.0), ('interpretable semantics', 1.0), ('noisy backpropagation', 1.0), ('similar task', 1.0), ('upon', 1.0), ('networks produce', 1.0), ('a search', 1.0), ('markovian state transitions', 1.0), ('a mass', 1.0), ('few features', 1.0), ('wiatowski', 1.0), ('null dynamical', 1.0), ('condition holds', 1.0), ('a match', 1.0), ('trade offs', 1.0), ('synaptic weights', 1.0), ('task confronted', 1.0), ('gradient or', 1.0), ('language acquisition', 1.0), ('deep learning architectures', 1.0), ('memory calls', 1.0), ('different vector', 1.0), ('next layer', 1.0), ('bodies', 1.0), ('test accuracy', 1.0), ('current exploration methods', 1.0), ('remarkable predictive', 1.0), ('english sentiment data', 1.0), ('visual dialog model', 1.0), ('reasonable performance', 1.0), ('this context', 1.0), ('tackles', 1.0), ('wise regularizer', 1.0), ('detection using', 1.0), ('event detection', 1.0), ('random manner', 1.0), ('composite representation', 1.0), ('generalization make', 1.0), ('sequential learning algorithm', 1.0), ('physical hexapod', 1.0), ('boltzmann machine', 1.0), ('safe regions', 1.0), ('lower perplexity', 1.0), ('low level characteristics', 1.0), ('non identifiability', 1.0), ('this adaptive', 1.0), ('report results', 1.0), ('tasks implying', 1.0), ('rotation invariant', 1.0), ('sole source', 1.0), ('side effect', 1.0), ('these measures', 1.0), ('complex local', 1.0), ('mnns', 1.0), ('models resorts', 1.0), ('challenge arises', 1.0), ('drawing samples', 1.0), ('black box inference', 1.0), ('automated framework', 1.0), ('different focuses', 1.0), ('carlo based', 1.0), ('significant common', 1.0), ('86.1', 1.0), ('models query', 1.0), ('single generative', 1.0), ('propose experiments', 1.0), ('of these', 1.0), ('for online', 1.0), ('the parameterized', 1.0), ('the google', 1.0), ('the main', 1.0), ('on neural language', 1.0), ('the partially', 1.0), ('in visual dialog', 1.0), ('of recent', 1.0), ('by these', 1.0), ('as full', 1.0), ('which we', 1.0), ('effectively using', 1.0), ('the uncertain', 1.0), ('among deep', 1.0), ('of nonlinear pca', 1.0), ('thus they', 1.0), ('several existing', 1.0), ('some behavior', 1.0), ('first pass', 1.0), ('training depends', 1.0), ('clinical relevance', 1.0), ('domains such', 1.0), ('frame level', 1.0), ('temperature density', 1.0), ('central algorithms', 1.0), ('inquiry', 1.0), ('discriminant analysis', 1.0), ('wide survey', 1.0), ('lnsmith54', 1.0), ('segmentation quality', 1.0), ('mathematical morphology', 1.0), ('algorithm parsec', 1.0), ('discriminator function', 1.0), ('inference process', 1.0), ('nov', 1.0), ('popular parallel second', 1.0), ('cloning method', 1.0), ('no accuracy', 1.0), ('semantic decoder component', 1.0), ('established baselines', 1.0), ('neural properties', 1.0), ('model worker', 1.0), ('deep domain adaptation', 1.0), ('resulting learner', 1.0), ('to ordinary', 1.0), ('spencer games', 1.0), ('datasets derived', 1.0), ('game playing', 1.0), ('posterior regularization', 1.0), ('search spaces', 1.0), ('data providing', 1.0), ('natural language strings', 1.0), ('existing clustering', 1.0), ('generated sentences', 1.0), ('target source', 1.0), ('autoencoder drae', 1.0), ('propose scatter', 1.0), ('stochastic gradient algorithms', 1.0), ('a configuration', 1.0), ('entropy criterion', 1.0), ('pooling strategies', 1.0), ('mvn2vec preservation', 1.0), ('small context window', 1.0), ('xor function', 1.0), ('hexapod robot 48d', 1.0), ('mini batch size', 1.0), ('a previous', 1.0), ('screening scheme', 1.0), ('automobile gps', 1.0), ('randomized models', 1.0), ('office caltech', 1.0), ('synaptic relationships', 1.0), ('solvation energy', 1.0), ('sensitivity analysis', 1.0), ('linguistically', 1.0), ('training signals', 1.0), ('quantitative results', 1.0), ('heuristic hand', 1.0), ('develop task', 1.0), ('expanded emotion', 1.0), ('to document', 1.0), ('allowing to', 1.0), ('performance is', 1.0), ('approach operates', 1.0), ('gating architectures', 1.0), ('alphasyllabary', 1.0), ('rnn cell', 1.0), ('discrete action spaces', 1.0), ('growcut segmentation', 1.0), ('term distances', 1.0), ('the tightness', 1.0), ('labeling model', 1.0), ('the 3d', 1.0), ('efficient bitwise operations', 1.0), ('world robotic', 1.0), ('vary components', 1.0), ('model first', 1.0), ('tasks domains', 1.0), ('purpose conditional', 1.0), ('visual turing test', 1.0), ('require matrix', 1.0), ('original size', 1.0), ('digital sky', 1.0), ('intrinsic low', 1.0), ('label scarcity', 1.0), ('multi linear', 1.0), ('wrong classification', 1.0), ('deep multi', 1.0), ('nonspeech separation', 1.0), ('synthesis unit', 1.0), ('full training', 1.0), ('free grammars', 1.0), ('regularization parameter', 1.0), ('malimg dataset', 1.0), ('recorded', 1.0), ('a matrix', 1.0), ('contexts data', 1.0), ('meta learning problem', 1.0), ('similar entities', 1.0), ('timescale credit', 1.0), ('motion capture', 1.0), ('sensory data instance', 1.0), ('several modifications', 1.0), ('manipulate objects', 1.0), ('c harness', 1.0), ('analyzer daa', 1.0), ('posterior', 1.0), ('combined use', 1.0), ('the squad', 1.0), ('first part', 1.0), ('high differentiation', 1.0), ('recent studies', 1.0), ('attention memory', 1.0), ('mixture models', 1.0), ('maturational', 1.0), ('the goals', 1.0), ('on two', 1.0), ('framework performs', 1.0), ('domain remains', 1.0), ('dark knowledge transfer', 1.0), ('paired video', 1.0), ('playful fashion', 1.0), ('local updates', 1.0), ('fundamental asymmetry', 1.0), ('given photograph', 1.0), ('among', 1.0), ('adversarial nets', 1.0), ('discuss benefits', 1.0), ('notable new', 1.0), ('benchmarks including', 1.0), ('inefficient distribution', 1.0), ('phenomenon represents', 1.0), ('using gaussian', 1.0), ('region size', 1.0), ('visual grouping', 1.0), ('side lobe', 1.0), ('ames', 1.0), ('exploit biases', 1.0), ('benchmark has', 1.0), ('engines based', 1.0), ('large action space', 1.0), ('the rnnai', 1.0), ('feedback negative', 1.0), ('20k evaluation', 1.0), ('translation equivariant', 1.0), ('reduce computation', 1.0), ('latent space', 1.0), ('level hierarchical', 1.0), ('projecting input', 1.0), ('protein', 1.0), ('specific concepts', 1.0), ('the smoothness', 1.0), ('discourages co', 1.0), ('sentence encoders', 1.0), ('multiplicative update rule', 1.0), ('robot teams', 1.0), ('the maximization', 1.0), ('oh', 1.0), ('standard speech', 1.0), ('a confidence', 1.0), ('for incremental', 1.0), ('vocable crowd disasters', 1.0), ('human teams', 1.0), ('evolutionary approach', 1.0), ('the phoneme', 1.0), ('output pairs', 1.0), ('context perform', 1.0), ('7.51', 1.0), ('consistent estimate', 1.0), ('acoustic tokenizer', 1.0), ('semantics defined', 1.0), ('previous attentive', 1.0), ('successful matching', 1.0), ('head pose', 1.0), ('completion dialogue', 1.0), ('standard domain adaptation', 1.0), ('simple ai babi', 1.0), ('other variants', 1.0), ('images generated', 1.0), ('scale machine', 1.0), ('this tutorial', 1.0), ('quantity grows', 1.0), ('bilingual recognition', 1.0), ('updates suffer', 1.0), ('adasecant robust adaptive secant', 1.0), ('new open', 1.0), ('quick reduct', 1.0), ('model components', 1.0), ('tag association', 1.0), ('arabic czech', 1.0), ('fcns', 1.0), ('video generation', 1.0), ('usps rimes', 1.0), ('non linear', 1.0), ('social mechanics', 1.0), ('isr system', 1.0), ('complex real', 1.0), ('compact circuit module', 1.0), ('search tree', 1.0), ('most of', 1.0), ('a wav2letter', 1.0), ('computing system', 1.0), ('infeasible amount', 1.0), ('convolutional elm', 1.0), ('many time steps', 1.0), ('berlin', 1.0), ('on model', 1.0), ('new family', 1.0), ('optimal performance', 1.0), ('operation objective', 1.0), ('cumbersome infrastructure', 1.0), ('hypotheses returned', 1.0), ('design cycle', 1.0), ('sign function', 1.0), ('potential regions', 1.0), ('srnn', 1.0), ('arise show', 1.0), ('independent movements', 1.0), ('traditional edas', 1.0), ('decoding method', 1.0), ('log normal', 1.0), ('structured domains', 1.0), ('aren t', 1.0), ('the principle', 1.0), ('senns', 1.0), ('linear disentangled', 1.0), ('simple ways', 1.0), ('alexnet structure regularization', 1.0), ('perturbations achieve', 1.0), ('probabilistic topic modelling', 1.0), ('entailment paraphrasing', 1.0), ('answering models', 1.0), ('better fidelity', 1.0), ('wen', 1.0), ('witness directions', 1.0), ('large computational', 1.0), ('topic inference', 1.0), ('adaptive imitation scheme', 1.0), ('analytic activation function', 1.0), ('a lm', 1.0), ('based edas', 1.0), ('infants', 1.0), ('concrete method', 1.0), ('on english', 1.0), ('the classifier', 1.0), ('improve diagnosis', 1.0), ('learning ability', 1.0), ('deep learning evaluation', 1.0), ('successful optimization', 1.0), ('such design', 1.0), ('squad ca', 1.0), ('informatics including', 1.0), ('highly tuned', 1.0), ('single dataset', 1.0), ('representation power', 1.0), ('controller has', 1.0), ('structures such', 1.0), ('weston et', 1.0), ('points search', 1.0), ('a tensor', 1.0), ('structure embedded', 1.0), ('video speech', 1.0), ('pattern classification', 1.0), ('dynamic objects', 1.0), ('new hypotheses', 1.0), ('coherence using', 1.0), ('systems achieve', 1.0), ('go indicates', 1.0), ('jklj077', 1.0), ('learning results', 1.0), ('deep neural networks dnn', 1.0), ('tokens word', 1.0), ('polish', 1.0), ('new stage', 1.0), ('hour bn', 1.0), ('dense vector representations', 1.0), ('local word', 1.0), ('ma chine learning', 1.0), ('task surpassing', 1.0), ('entailment show', 1.0), ('abstract representation', 1.0), ('new words', 1.0), ('natural language nl', 1.0), ('learning integrating', 1.0), ('the classes', 1.0), ('recognition system', 1.0), ('to several language', 1.0), ('neural style transfer', 1.0), ('networks allow', 1.0), ('decoder family', 1.0), ('2', 1.0), ('aware keyword', 1.0), ('nearest neighbor methods', 1.0), ('models dealing', 1.0), ('adp', 1.0), ('relevant source information', 1.0), ('new combinations', 1.0), ('wenwei202', 1.0), ('simple wikipedia', 1.0), ('snn simulation', 1.0), ('fast evaluation time', 1.0), ('network advances', 1.0), ('sukhbaatar', 1.0), ('powerful invertible', 1.0), ('total amount', 1.0), ('distributions encoded', 1.0), ('surpasses the', 1.0), ('full precision networks', 1.0), ('convex function', 1.0), ('linear formulations', 1.0), ('the usage', 1.0), ('annotation training', 1.0), ('medical prescriptions', 1.0), ('the testing', 1.0), ('length sequences', 1.0), ('high multiplicity regime', 1.0), ('custom oriented', 1.0), ('current performance representation', 1.0), ('the child', 1.0), ('explicit reward', 1.0), ('the root', 1.0), ('performing systems', 1.0), ('a curve', 1.0), ('prediction network', 1.0), ('the octopus', 1.0), ('paper surveys', 1.0), ('table querying', 1.0), ('component leading', 1.0), ('selling products', 1.0), ('first problem', 1.0), ('mathematical concept', 1.0), ('the lm', 1.0), ('inductive reasoning ci', 1.0), ('the set', 1.0), ('the assumption', 1.0), ('approximation adds', 1.0), ('low level sensor', 1.0), ('future satellite images', 1.0), ('separating feature', 1.0), ('plausible images', 1.0), ('conventional stack data', 1.0), ('surprised confused', 1.0), ('high learning', 1.0), ('quadratically convergent', 1.0), ('a survey', 1.0), ('video clip', 1.0), ('global landscapes', 1.0), ('existing datasets', 1.0), ('provided grade', 1.0), ('acoustic gmm hmm', 1.0), ('challenging subspace', 1.0), ('loss methods', 1.0), ('first neural', 1.0), ('widespread practical', 1.0), ('composition process', 1.0), ('changing world', 1.0), ('resulting pixeldcl', 1.0), ('machine dybm', 1.0), ('particular application', 1.0), ('level lstm', 1.0), ('computing nodes', 1.0), ('unified neural', 1.0), ('insurance', 1.0), ('the metaphor', 1.0), ('tasks interpretability', 1.0), ('studied learning', 1.0), ('no insight', 1.0), ('of q', 1.0), ('skip connections', 1.0), ('called correlation', 1.0), ('neural computation', 1.0), ('standard beam', 1.0), ('real user', 1.0), ('factor model', 1.0), ('facing novel', 1.0), ('scientific community', 1.0), ('benefiting', 1.0), ('target word', 1.0), ('misdiagnosis', 1.0), ('embeddings based', 1.0), ('memory am', 1.0), ('both accuracy', 1.0), ('related concepts', 1.0), ('exploiting correlations', 1.0), ('pca analysis', 1.0), ('great interest', 1.0), ('planning require', 1.0)]
words = v9f_words
len(words)
# Out:
# 2514

# %%
prec_words = sorted(words, key = lambda x: -prec_map[x[0]])

# %%
rec_words = sorted(words, key = lambda x: -rec_map[x[0]])

# %%
rec_words = [(w[0], w[1], rec_map[w[0]]) for w in rec_words]

# %%
prec_words = [(w[0], w[1], prec_map[w[0]]) for w in prec_words]

# %%
prec_words[:5]
# Out:
# [('artificial intelligence', 100, 1.0),
#  ('principal component analysis', 100, 1.0),
#  ('algorithms', 100, 1.0),
#  ('hierarchical deep reinforcement learning', 100, 1.0),
#  ('machine learning', 100, 1.0)]

# %%
with open("../final_stuff/outputs/ashu_jun17-21_prec.txt", "w") as f:
    for w in prec_words:
        f.write(w[0] + "\t" + str(w[1]) + "\t" + str(w[2]) + "\n")

# %%
with open("../final_stuff/outputs/ashu_jun17-21_rec.txt", "w") as f:
    for w in rec_words:
        f.write(w[0] + "\t" + str(w[1]) + "\t" + str(w[2]) + "\n")

# %%
def get_sets(words_set, mode):
    good = set()
    bad = set()
    very_bad = set()
    
    for i, word in enumerate(words_set):
        try:
            url_suffix = (word.replace(" ", "_").replace("-", "_")).capitalize()
            url = "https://en.wikipedia.org/wiki/" + url_suffix
            status = 0
            try:
                code = urllib.request.urlopen(url).getcode()
                if code == 200:
                    good.add(word)
                    status = 1
            except HTTPError:
                if status == 0 and word[-1] == 's' and len(word.split(" ")) > 1:
                    url = url[:-1]
                    try:
                        code = urllib.request.urlopen(url).getcode()
                        if code == 200:
                            good.add(word)
                            status = 1
                    except HTTPError:
                        bad.add(word)
            print("Ran " + str(i + 1) + "... Keyword: " + word + " URL: " + url + " Status: " + str(status))
        except:
            very_bad.add(word)
    
    probably_good = set()
    for word in words_set.difference(good):
        query = word.replace("-", " ").lower()
        query_tok = nlp(query)
        values = []
        for result in wikipedia.search(query):
            result_tok = nlp(result.lower().replace("-", " "))
            d = result_tok.similarity(query_tok) * 100 
            values.append(d)
        if len(values) != 0:
            print("Rechecking... " + "Keyword: " + word + " Max Similarity: " + str(max(values)))
            if max(values) > 80.0:
                probably_good.add(word)

    return good, probably_good

def get_precision(words_set, mode, good=None, probably_good=None):
    if good is None or probably_good is None:
        good, probably_good = get_sets(words_set, mode)
    precision = ((len(good) + len(probably_good)) / len(words_set)) * 100.0
    return precision, good, probably_good

def get_recall(prdr_good_set, ap_good_set):
    if prdr_good_set is None or ap_good_set is None:
        return None
    prdr_recall = (len(prdr_good_set))/(len(prdr_good_set.union(ap_good_set))) * 100.0
    ap_recall = (len(prdr_good_set))/(len(prdr_good_set.union(ap_good_set))) * 100.0
    return prdr_recall, ap_recall

# %%
# Recall for general phrase mining task 
num_words = 100
candidate_keyphrases = set([t[0] for t in words[:num_words]])
prec, good_set, prolly_good_set = get_precision(candidate_keyphrases, 0, None, None)
# Out:
# Ran 1... Keyword: based URL: https://en.wikipedia.org/wiki/Based Status: 1
# Ran 3... Keyword: dependencies URL: https://en.wikipedia.org/wiki/Dependencies Status: 1
# Ran 7... Keyword: natural language generation URL: https://en.wikipedia.org/wiki/Natural_language_generation Status: 1
# Ran 8... Keyword: vision URL: https://en.wikipedia.org/wiki/Vision Status: 1
# Ran 10... Keyword: predict URL: https://en.wikipedia.org/wiki/Predict Status: 1
# Ran 12... Keyword: python code URL: https://en.wikipedia.org/wiki/Python_code Status: 1
# Ran 14... Keyword: sparsity URL: https://en.wikipedia.org/wiki/Sparsity Status: 1
# Ran 17... Keyword: constraint programming URL: https://en.wikipedia.org/wiki/Constraint_programming Status: 1
# Ran 20... Keyword: images URL: https://en.wikipedia.org/wiki/Images Status: 1
# Ran 21... Keyword: dependency URL: https://en.wikipedia.org/wiki/Dependency Status: 1
# ...

# %%
# Warning: above code takes a really long time to run! (probably best to skip this part)
prec
# Out:
# 83.0

# %%
precision_prec = []
for length in range(100, 900, 100):
    count = 0
    for (word, _, _) in prec_words[:length]:
        if word in good_set:
            count += 1
    precision_prec.append(count/length)

# %%
precision_prec
# Out:
# [0.16,
#  0.135,
#  0.12333333333333334,
#  0.1075,
#  0.106,
#  0.12166666666666667,
#  0.12,
#  0.19625]

# %%
precision_rec = []
for length in range(100, 900, 100):
    count = 0
    for (word, _, _) in rec_words[:length]:
        if word in good_set:
            count += 1
    precision_rec.append(count/length)

# %%
precision_prdr = []
for length in range(100, 900, 100):
    count = 0
    for (word, _) in words[:length]:
        if word in good_set:
            count += 1
    precision_prdr.append(count/length)

# %%
precision_rec
# Out:
# [0.48, 0.575, 0.56, 0.545, 0.462, 0.485, 0.45714285714285713, 0.41125]

# %%
precision_prdr
# Out:
# [0.18,
#  0.16,
#  0.18333333333333332,
#  0.195,
#  0.206,
#  0.22333333333333333,
#  0.26142857142857145,
#  0.29125]

# %%
# Porter stemmer 
from nltk.stem import PorterStemmer 

sample_texts = ["neural networks", "neural network"]
ps = PorterStemmer()

for text in sample_texts:
    sample_stem = ps.stem(text)
    print(sample_stem)
# Out:
# neural network
# neural network

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process 
from itertools import combinations


def revised_phrase_similarity(phrase1, phrase2):
    
    # New phrase similarity measure (uses stemming + edit distance)
    phrase1_stem = ps.stem(phrase1)
    phrase2_stem = ps.stem(phrase2)
    
    if phrase1_stem == phrase2_stem:
        return ("", fuzz.ratio(phrase1, phrase2))
    else:
        return ("", 0)

# Needs revisiting, not very good
def phrase_similarity(phrase1, phrase2):
    
    # New phrase similarity measure (uses stemming + edit distance)
    # return revised_phrase_similarity(phrase1, phrase2)
    
    tokens1 = phrase1.split(' ')
    tokens2 = phrase2.split(' ')
    
    shorter = []
    longer = []
    if len(tokens1) <= len(tokens2):
        shorter = tokens1
        longer = tokens2
    else:
        shorter = tokens2
        longer = tokens1
    
    short_substrings = [' '.join(shorter[x:y]) for x, y in combinations(range(len(shorter) + 1), r = 2)]
    long_substrings = [' '.join(longer[x:y]) for x, y in combinations(range(len(longer) + 1), r = 2)]
    
    combined = list(set(short_substrings + long_substrings))
    combined.sort(key = lambda s: -len(s))

    for substr in combined:
        if substr in phrase1 and substr in phrase2:
            if len(substr) > 2:
                return (substr, 100*len(substr.split(' '))/min(len(tokens1), len(tokens2)))
            else:
                return ("", 0)
    
    return ("", 0)

def get_count(phrase):
    global ngrams
    try:
        idx = len(phrase.split(" ")) - 1
        return ngrams[idx][phrase]
    except:
        return 0

def get_keyword_recall(gold_phrases, candidate_words, occurrence_threshold=2, similarity_threshold=80):
    
    good_words = set()
    seen_gold_phrases = []
    for phrase in gold_phrases:
        if get_count(phrase) >= occurrence_threshold: # and len(phrase) > 1
            seen_gold_phrases.append(phrase)
    
    seen_gold_phrases = list(set(seen_gold_phrases))
    print(len(seen_gold_phrases), seen_gold_phrases[:60])
    gold_to_match = {}
    
    for phrase in seen_gold_phrases:
        gold_to_match[phrase] = ("", 0.0)
    
    keyword_recall = []
    for length in range(100, 1000, 100):
        match_count = 0
        for phrase in seen_gold_phrases:
            best_score = -100
            best_candidate = ""
            for candidate in candidate_words[:length]:
                temp, sim_score = phrase_similarity(phrase, candidate)
                if sim_score > best_score: # and len(candidate.split(' ')) > 1:
                    best_score = sim_score
                    best_candidate = candidate
                    
            # print("Matching {} to {}".format(phrase, best_candidate))
                    
            if best_score > gold_to_match[phrase][1]:
                gold_to_match[phrase] = (best_candidate, best_score)
                
            if best_score > similarity_threshold:
                good_words.add(best_candidate)
                match_count += 1
                
        
        recall_t = (length, 100 * (match_count / len(seen_gold_phrases)))
        keyword_recall.append(recall_t)
        print(recall_t)

    # for length in range(1000, 8000, 1000):
    if False:
        match_count = 0
        for phrase in seen_gold_phrases:
            best_score = -100
            best_candidate = ""
            for candidate in candidate_words[:length]:
                temp, sim_score = phrase_similarity(phrase, candidate)
                if sim_score > best_score: # and len(candidate.split(' ')) > 1:
                    best_score = sim_score
                    best_candidate = candidate
            if best_score > gold_to_match[phrase][1]:
                gold_to_match[phrase] = (best_candidate, best_score)
            if best_score > 50:
                good_words.add(best_candidate)
                match_count += 1
        keyword_recall.append((length, 100*match_count/len(seen_gold_phrases)))
        print((length, 100*match_count/len(seen_gold_phrases)))
    
    return keyword_recall, good_words, gold_to_match, len(seen_gold_phrases)

# %%
gold_phrases = []
with open("../final_stuff/data/wikipedia_reference/gold_wiki_phrases.txt") as f:
    gold_phrases = [line[:-1] for line in f.readlines()]

oxford_words = []
with open("../final_stuff/data/wikipedia_reference/oxford_vocab.txt", "r") as f:
    count = 0
    for line in f.readlines():
        if (line != "\n"):
            oxford_words.append(line[:-1])
import re
for w in oxford_words:
    gold_phrases.append((re.sub(r'[^A-Za-z0-9 ]+', '', w).lower()))
    
gold_phrases = list(set([phr for phr in gold_phrases if len(phr) > 1]))

# %%
len(gold_phrases)
# Out:
# 4629

# %%
with open("../final_stuff/data/arxiv_titles_and_abstracts_short.txt") as f:
    lines = f.readlines()

lines = [ x[:-1] for x in lines]
lines = [x.split(".") for x in lines]
lines = [sentence.split(" ") for sentences in lines for sentence in sentences]

from collections import defaultdict
unigram_counts = defaultdict(int)
for line in lines:
    for word in line:
        if word != "":
            unigram_counts[word] += 1

bigram_counts = defaultdict(int)
for line in lines:
    prev_word = line[0]
    for word in line[1:]:
        bigram_counts[prev_word + " " + word] += 1
        prev_word = word

trigram_counts = defaultdict(int)
for line in lines:
    if len(line) < 3:
        continue
    prev_prev_word = line[0]
    prev_word = line[1]
    for word in line[2:]:
        trigram_counts[prev_prev_word + " " + prev_word + " " + word] += 1
        prev_prev_word = prev_word
        prev_word = word

# %%
ngrams = [unigram_counts, bigram_counts, trigram_counts]

for i in range(3):
    print(len(ngrams[i]))
# Out:
# 8221
# 67250
# 112875

# %%
# candidate_keyphrases = list(set([t[0] for t in words]))
candidate_keyphrases = [t[0] for t in words]
print(candidate_keyphrases[:50])
# Out:
# ['supervised machine learning models', 'long range dependencies', 'neural networks', 'hierarchical deep reinforcement learning', 'distributed database systems', 'machine learning', 'algorithms', 'artificial intelligence', 'constraint programming', 'principal component analysis', 'attention mechanisms', 'natural language processing', 'sequence to sequence learning', 'databases', 'automatic speech recognition', 'parameter sharing', 'networks', 'natural language generation', 'residual networks', 'based', 'task learning', 'object detection', 'statistical machine translation', 'images', 'neural models', 'processing', 'feature', 'recurrent network architectures', 'visual dialog', 'standard computer vision', 'image data', 'object', 'parameters', 'data sets', 'neural image captioning', 'conditional language models', 'computer', 'application', 'hierarchical latent variable', 'electronic health records', 'work', 'latent', 'accuracy', 'matching', 'model architecture', 'imagenet', 'complex tasks
# ...

# %%
# Computing precision and recall with relation to keyphrases 
# (instead of just phrases, which are domain independent)
keyword_recall_ts, good_words, gold_to_match, num_good_in_corpus = get_keyword_recall(gold_phrases, candidate_keyphrases)
print("Saw {} keyphrases".format(num_good_in_corpus))
print(gold_to_match)
# Out:
# 433 ['turing machine', 'forests', 'leading', 'dedicated', 'robots', 'python', 'document', 'voxel', 'sequential', 'man', 'shift', 'key', 'quantification', 'http', 'encoding', 'signal', 'or', 'eds', 'ancestor', 'expression', 'benchmark', 'cbt', 'proof', 'closed loop', 'consistency', 'sca', 'dynamic memory', 'warping', 'remote', 'schema', 'speech recognition', 'supervised learning', 'share', 'language', 'module', 'curvature', 'optical flow', 'safety', 'programming languages', 'table', 'base', 'windows', 'graphics', 'scheme', 'engine', 'representation', 'induction', 'net', 'message passing', 'covariance', 'route', 'type', 'reliability', 'support vector machines', 'morphology', 'access', 'sql', 'searching', 'science', 'synchronization']
# (100, 20.092378752886837)
# (200, 27.48267898383372)
# (300, 34.41108545034642)
# (400, 39.4919168591224)
# (500, 42.956120092378754)
# (600, 46.4203233256351)
# (700, 49.88452655889146)
# (800, 52.88683602771363)
# (900, 55.19630484988453)
# ...

# %%
# Calculating keyword precision from keyword recall 
keyword_precisions = []
keyword_recalls = []

for kw_recall_t in keyword_recall_ts[:8]:
    curr_kw_prec = ((kw_recall_t[1] / 100) * num_good_in_corpus) / kw_recall_t[0]
    
    keyword_precisions.append(curr_kw_prec * 100)
    keyword_recalls.append(kw_recall_t[1])
    
print("Keyphrase recalls: ", keyword_recalls)
print("Keyphrase precisions: ", keyword_precisions)
# Out:
# Keyphrase recalls:  [20.092378752886837, 27.48267898383372, 34.41108545034642, 39.4919168591224, 42.956120092378754, 46.4203233256351, 49.88452655889146, 52.88683602771363]
# Keyphrase precisions:  [87.00000000000001, 59.5, 49.666666666666664, 42.75, 37.2, 33.5, 30.857142857142854, 28.625]

# %%
# Visualization Example: (below code has been tried successfully in a Jupyter notebook)

import matplotlib.pyplot as plt
# %matplotlib inline

# x = y
x = list(range(100, 900, 100))
     
v6_keyphrase_recalls = [3.0023094688221708, 4.849884526558892, 5.773672055427252, 6.697459584295612, 7.390300230946882, 8.775981524249422, 9.699769053117784, 10.854503464203233]
v9f_keyphrase_recalls = [4.618937644341801, 6.928406466512701, 8.775981524249422, 11.778290993071593, 12.933025404157044, 13.625866050808314, 13.625866050808314, 13.625866050808314]
# combined_precision = precision_prec

# old_precision = [86.0, 82.0, 82.0, 81.75, 81.2]
# old_recall = [49.43, 53.07, 51.57, 51.58, 50.69]
# old_f1 = [62.77, 64.44, 63.32, 63.25, 63.25]

plt.figure(figsize=(10,10))
plt.scatter(x, v6_keyphrase_recalls, c='b', marker='x', label='v6')
plt.plot(x, v6_keyphrase_recalls, c='b')
plt.scatter(x, v9f_keyphrase_recalls, c='r', marker='s', label='v9')
plt.plot(x, v9f_keyphrase_recalls, c='r')
# plt.scatter(x, combined_precision, c='g', marker='v', label='Combined')
# plt.plot(x, combined_precision, c='g')
plt.legend(loc='upper right')

plt.xlabel('Number of (Top Ranked) Keywords', fontsize=12)
plt.ylabel('Precision %', fontsize=12)

for i_x, i_y in zip(x, v6_keyphrase_recalls):
    plt.text(i_x, i_y, '{}'.format(round(i_y,2)), color = 'blue')

for i_x, i_y in zip(x, v9f_keyphrase_recalls):
    plt.text(i_x, i_y, '{}'.format(round(i_y,2)), color = 'red')

# for i_x, i_y in zip(x, combined_precision):
#     plt.text(i_x, i_y, '{}'.format(round(i_y,2)), color = 'green')

# plt.show()
plt.savefig('combined_precision_graph.png')
